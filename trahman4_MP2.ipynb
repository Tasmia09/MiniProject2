# %%
import sys
import re
import pymongo
import json
import time
import datetime
import requests
from bs4 import BeautifulSoup

dbname = "fdac18mp2" #please use this database
collname = "glprj_trahman4" #please modify so you store data in your collection
my_char = 'g'

# beginning page index
begin = "1"
client = pymongo.MongoClient()

db = client[dbname]
coll = db[collname]


gitlab_url = "https://gitlab.com/api/v4/projects?archived=false&membership=false&order_by=created_at&owned=false&page=" + begin + \
    "&per_page=99&simple=false&sort=desc&starred=false&statistics=false&with_custom_attributes=false&with_issues_enabled=false&with_merge_requests_enabled=false"

gleft = 20

source_url = "https://sourceforge.net/directory/?q=" + my_char + "&sort=name&page="
rest_url = "https://sourceforge.net/rest/p/"

header = {'per_page': 99}

# check remaining query chances for rate-limit restriction
def wait(left):
    global header
    while (left < 20):
        l = requests.get('https://gitlab.com/api/v4/projects', headers=header)
        if (l.ok):
            left = int(l.headers.get('RateLimit-Remaining'))
        time .sleep(60)
    return left

def project_exists(url):
    r = requests.get(url)
    if r.status_code == 200:
        return True
    return False

# def get_source(url, coll, rest):
#     page = 1
#     project_count = 0
#     while True:
#         resp = requests.get(url + str(page))
#         text = resp.text
#         soup = BeautifulSoup(text, 'html.parser')
#         if re.search('No results found.', soup.get_text()):
#             return

#         for link in soup.find_all(class_="project-icon", href=True):
#             name = re.findall('/projects/([A-Za-z0-9\-]*)', link.get('href'))
#             name = name[0] if name else None
#             if name is not None and name.lower().startswith(my_char):
#                 resp = requests.get(rest + name)
#                 if resp.status_code == 200:
#                     info = json.loads(resp.text)
#                     info['forge'] = 'sourceforge'
#                     coll.insert_one(info)
#                     project_count += 1
#                     if project_count >= 50:
#                         return
#         page += 1
#     return

# send queries and extract urls 
def get_gitlab(url, coll):

    global gleft
    global header
    global bginnum
    gleft = wait(gleft)
    values = []
    size = 0
    project_count = 0

    try:
        r = requests .get(url, headers=header)
        time .sleep(0.5)
        # got blocked
        if r.status_code == 403:
            return "got blocked", str(bginnum)
        if (r.ok):

            gleft = int(r.headers.get('RateLimit-Remaining'))
            lll = r.headers.get('Link')
            t = r.text
            array = json.loads(t)
            
            for el in array:
                if el['name'].lower().startswith(my_char):
                    if project_exists(el['http_url_to_repo']):
                        project_count += 1
                        el['forge'] = 'gitlab'
                        coll.insert_one(el)
                        if project_count >= 50:
                            return
            
            #next page
            while ('; rel="next"' in lll):
                gleft = int(r.headers.get('RateLimit-Remaining'))
                gleft = wait(gleft)
                # extract next page url
                ll = lll.replace(';', ',').split(',')
                url = ll[ll.index(' rel="next"') -
                         1].replace('<', '').replace('>', '').lstrip()
             
                try:
                    r = requests .get(url, headers=header)
                    if r.status_code == 403:
                        return "got blocked", str(bginnum)
                    if (r.ok):
                        lll = r.headers.get('Link')
                        t = r.text
                        array1 = json.loads(t)
                        for el in array1:
                            if el['name'].lower().startswith(my_char):
                                if project_exists(el['http_url_to_repo']):
                                    project_count += 1
                                    el['forge'] = 'gitlab'
                                    coll.insert_one(el)
                                    if project_count >= 50:
                                        return
                    else:
                        sys.stderr.write("url can not found:\n" + url + '\n')
                        return 
                except requests.exceptions.ConnectionError:
                    sys.stderr.write('could not get ' + url + '\n')
            
        else:
            sys.stderr.write("url can not found:\n" + url + '\n')
            return

    except requests.exceptions.ConnectionError:
        sys.stderr.write('could not get ' + url + '\n')
    except Exception as e:
        sys.stderr.write(url + ';' + str(e) + '\n')
        
#start retrieving        
get_gitlab(gitlab_url,coll)
#get_source(source_url, coll, rest_url)
#print collected data
for doc in coll.find({}):
    print(doc)
# Out:
# {'forks_count': 0, 'created_at': '2018-10-17T19:02:00.230Z', 'readme_url': None, 'last_activity_at': '2018-10-17T19:02:00.230Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'Game_Website', 'description': 'Check data from games, HTML, MYSQL, PHP, jscript', 'http_url_to_repo': 'https://gitlab.com/michaelmercier/game_website.git', '_id': ObjectId('5bc787ab2683be47187d4b3c'), 'path_with_namespace': 'michaelmercier/game_website', 'name_with_namespace': 'mike / Game_Website', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 958316, 'parent_id': None, 'full_path': 'michaelmercier', 'path': 'michaelmercier', 'name': 'michaelmercier'}, 'id': 8918171, 'path': 'game_website', 'web_url': 'https://gitlab.com/michaelmercier/game_website', 'ssh_url_to_repo': 'git@gitlab.com:michaelmercier/game_website.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T18:57:44.620Z', 'readme_url': None, 'last_activity_at': '2018-10-17T18:57:44.620Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'g2-saltmaster-states', 'description': '', 'http_url_to_repo': 'https://gitlab.com/napindc/g2-saltmaster-states.git', '_id': ObjectId('5bc787ac2683be47187d4b3d'), 'path_with_namespace': 'napindc/g2-saltmaster-states', 'name_with_namespace': 'Mike / g2-saltmaster-states', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1960225, 'parent_id': None, 'full_path': 'napindc', 'path': 'napindc', 'name': 'napindc'}, 'id': 8918107, 'path': 'g2-saltmaster-states', 'web_url': 'https://gitlab.com/napindc/g2-saltmaster-states', 'ssh_url_to_repo': 'git@gitlab.com:napindc/g2-saltmaster-states.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T18:38:35.760Z', 'readme_url': None, 'last_activity_at': '2018-10-17T18:38:35.760Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GestureTest', 'description': None, 'http_url_to_repo': 'https://gitlab.com/FuadYoussef/GestureTest.git', '_id': ObjectId('5bc787ac2683be47187d4b3e'), 'path_with_namespace': 'FuadYoussef/GestureTest', 'name_with_namespace': 'Fuad Youssef / GestureTest', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3827745, 'parent_id': None, 'full_path': 'FuadYoussef', 'path': 'FuadYoussef', 'name': 'FuadYoussef'}, 'id': 8917861, 'path': 'GestureTest', 'web_url': 'https://gitlab.com/FuadYoussef/GestureTest', 'ssh_url_to_repo': 'git@gitlab.com:FuadYoussef/GestureTest.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T18:23:54.668Z', 'readme_url': 'https://gitlab.com/andrewlader/go-gently/blob/master/README.md', 'last_activity_at': '2018-10-17T18:23:54.668Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'go-gently', 'description': 'The Go-Gently service is a Go language package to enable other Go services to gently shutdown when they receive a SIGTERM, SIGINT or SIGQUIT signal.', 'http_url_to_repo': 'https://gitlab.com/andrewlader/go-gently.git', '_id': ObjectId('5bc787ac2683be47187d4b3f'), 'path_with_namespace': 'andrewlader/go-gently', 'name_with_namespace': 'Andrew Lader / go-gently', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1900987, 'parent_id': None, 'full_path': 'andrewlader', 'path': 'andrewlader', 'name': 'andrewlader'}, 'id': 8917693, 'path': 'go-gently', 'web_url': 'https://gitlab.com/andrewlader/go-gently', 'ssh_url_to_repo': 'git@gitlab.com:andrewlader/go-gently.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:48:17.422Z', 'readme_url': 'https://gitlab.com/Froglich/gorma/blob/master/README.md', 'last_activity_at': '2018-10-17T17:48:17.422Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gorma', 'description': 'A cron-like scheduler for Windows.', 'http_url_to_repo': 'https://gitlab.com/Froglich/gorma.git', '_id': ObjectId('5bc787ac2683be47187d4b40'), 'path_with_namespace': 'Froglich/gorma', 'name_with_namespace': 'Kim Lindgren / gorma', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3583042, 'parent_id': None, 'full_path': 'Froglich', 'path': 'Froglich', 'name': 'Froglich'}, 'id': 8917251, 'path': 'gorma', 'web_url': 'https://gitlab.com/Froglich/gorma', 'ssh_url_to_repo': 'git@gitlab.com:Froglich/gorma.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:18:34.002Z', 'readme_url': 'https://gitlab.com/ricardo_jr37/gti_of/blob/master/README.md', 'last_activity_at': '2018-10-17T17:18:34.002Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gti_of', 'description': '', 'http_url_to_repo': 'https://gitlab.com/ricardo_jr37/gti_of.git', '_id': ObjectId('5bc787b12683be47187d4b41'), 'path_with_namespace': 'ricardo_jr37/gti_of', 'name_with_namespace': 'Antonio Ricardo Coelho Alcantara Junior / gti_of', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3512488, 'parent_id': None, 'full_path': 'ricardo_jr37', 'path': 'ricardo_jr37', 'name': 'ricardo_jr37'}, 'id': 8916779, 'path': 'gti_of', 'web_url': 'https://gitlab.com/ricardo_jr37/gti_of', 'ssh_url_to_repo': 'git@gitlab.com:ricardo_jr37/gti_of.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.864Z', 'readme_url': 'https://gitlab.com/tycho01/gym/blob/master/README.rst', 'last_activity_at': '2018-10-17T17:02:42.864Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gym', 'description': 'A toolkit for developing and comparing reinforcement learning algorithms.', 'http_url_to_repo': 'https://gitlab.com/tycho01/gym.git', '_id': ObjectId('5bc787b72683be47187d4b42'), 'path_with_namespace': 'tycho01/gym', 'name_with_namespace': 'Tycho Grouwstra / gym', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916456, 'path': 'gym', 'web_url': 'https://gitlab.com/tycho01/gym', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/gym.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.760Z', 'readme_url': 'https://gitlab.com/tycho01/gs-spring-boot/blob/master/README.adoc', 'last_activity_at': '2018-10-17T17:02:42.760Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gs-spring-boot', 'description': 'Building an Application with Spring Boot :: Learn how to build an application with minimal configuration.', 'http_url_to_repo': 'https://gitlab.com/tycho01/gs-spring-boot.git', '_id': ObjectId('5bc787b72683be47187d4b43'), 'path_with_namespace': 'tycho01/gs-spring-boot', 'name_with_namespace': 'Tycho Grouwstra / gs-spring-boot', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916455, 'path': 'gs-spring-boot', 'web_url': 'https://gitlab.com/tycho01/gs-spring-boot', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/gs-spring-boot.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.658Z', 'readme_url': 'https://gitlab.com/tycho01/gs-accessing-data-jpa/blob/master/README.adoc', 'last_activity_at': '2018-10-17T17:02:42.658Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gs-accessing-data-jpa', 'description': 'Accessing Data with JPA :: Learn how to work with JPA data persistence using Spring Data JPA.', 'http_url_to_repo': 'https://gitlab.com/tycho01/gs-accessing-data-jpa.git', '_id': ObjectId('5bc787bc2683be47187d4b44'), 'path_with_namespace': 'tycho01/gs-accessing-data-jpa', 'name_with_namespace': 'Tycho Grouwstra / gs-accessing-data-jpa', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916454, 'path': 'gs-accessing-data-jpa', 'web_url': 'https://gitlab.com/tycho01/gs-accessing-data-jpa', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/gs-accessing-data-jpa.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.547Z', 'readme_url': 'https://gitlab.com/tycho01/google-taxonomy-matcher/blob/master/README.md', 'last_activity_at': '2018-10-17T17:02:42.547Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'google-taxonomy-matcher', 'description': "Matches a category of Google's Taxonomy to product that is described in any kind of text data", 'http_url_to_repo': 'https://gitlab.com/tycho01/google-taxonomy-matcher.git', '_id': ObjectId('5bc787bc2683be47187d4b45'), 'path_with_namespace': 'tycho01/google-taxonomy-matcher', 'name_with_namespace': 'Tycho Grouwstra / google-taxonomy-matcher', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916453, 'path': 'google-taxonomy-matcher', 'web_url': 'https://gitlab.com/tycho01/google-taxonomy-matcher', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/google-taxonomy-matcher.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.436Z', 'readme_url': 'https://gitlab.com/tycho01/glossary/blob/master/README.md', 'last_activity_at': '2018-10-17T17:02:42.436Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'glossary', 'description': 'https://machinelearning.wtf/  - An online glossary of machine learning terms.', 'http_url_to_repo': 'https://gitlab.com/tycho01/glossary.git', '_id': ObjectId('5bc787bd2683be47187d4b46'), 'path_with_namespace': 'tycho01/glossary', 'name_with_namespace': 'Tycho Grouwstra / glossary', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916452, 'path': 'glossary', 'web_url': 'https://gitlab.com/tycho01/glossary', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/glossary.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:59:31.310Z', 'readme_url': 'https://gitlab.com/pvbinh1985/game/blob/master/README.md', 'last_activity_at': '2018-10-17T16:59:31.310Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'game', 'description': '', 'http_url_to_repo': 'https://gitlab.com/pvbinh1985/game.git', '_id': ObjectId('5bc787bd2683be47187d4b47'), 'path_with_namespace': 'pvbinh1985/game', 'name_with_namespace': 'Phan Binh / game', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3827222, 'parent_id': None, 'full_path': 'pvbinh1985', 'path': 'pvbinh1985', 'name': 'pvbinh1985'}, 'id': 8916360, 'path': 'game', 'web_url': 'https://gitlab.com/pvbinh1985/game', 'ssh_url_to_repo': 'git@gitlab.com:pvbinh1985/game.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:46:53.400Z', 'readme_url': 'https://gitlab.com/s.v.ivko/go-course/blob/week_5/README.md', 'last_activity_at': '2018-10-17T16:46:53.400Z', 'tag_list': [], 'default_branch': 'week_5', 'forge': 'gitlab', 'star_count': 0, 'name': 'go-course', 'description': '', 'http_url_to_repo': 'https://gitlab.com/s.v.ivko/go-course.git', '_id': ObjectId('5bc787bd2683be47187d4b48'), 'path_with_namespace': 's.v.ivko/go-course', 'name_with_namespace': 'Serg Ivko / go-course', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2935159, 'parent_id': None, 'full_path': 's.v.ivko', 'path': 's.v.ivko', 'name': 's.v.ivko'}, 'id': 8916180, 'path': 'go-course', 'web_url': 'https://gitlab.com/s.v.ivko/go-course', 'ssh_url_to_repo': 'git@gitlab.com:s.v.ivko/go-course.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:46:38.009Z', 'readme_url': 'https://gitlab.com/dieggsy/geiser/blob/master/README.org', 'last_activity_at': '2018-10-17T16:46:38.009Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'geiser', 'description': 'emacs and scheme talk to each other', 'http_url_to_repo': 'https://gitlab.com/dieggsy/geiser.git', '_id': ObjectId('5bc787be2683be47187d4b49'), 'path_with_namespace': 'dieggsy/geiser', 'name_with_namespace': 'diego / geiser', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 761463, 'parent_id': None, 'full_path': 'dieggsy', 'path': 'dieggsy', 'name': 'dieggsy'}, 'id': 8916177, 'path': 'geiser', 'web_url': 'https://gitlab.com/dieggsy/geiser', 'ssh_url_to_repo': 'git@gitlab.com:dieggsy/geiser.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:42:34.623Z', 'readme_url': 'https://gitlab.com/Erwan_Chesnay/GodGameLPRGI/blob/master/README.md', 'last_activity_at': '2018-10-17T16:42:34.623Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GodGameLPRGI', 'description': "C'est un projet trop bien (mais dur)", 'http_url_to_repo': 'https://gitlab.com/Erwan_Chesnay/GodGameLPRGI.git', '_id': ObjectId('5bc787be2683be47187d4b4a'), 'path_with_namespace': 'Erwan_Chesnay/GodGameLPRGI', 'name_with_namespace': 'Erwan Chesnay / GodGameLPRGI', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1961416, 'parent_id': None, 'full_path': 'Erwan_Chesnay', 'path': 'Erwan_Chesnay', 'name': 'Erwan_Chesnay'}, 'id': 8916106, 'path': 'GodGameLPRGI', 'web_url': 'https://gitlab.com/Erwan_Chesnay/GodGameLPRGI', 'ssh_url_to_repo': 'git@gitlab.com:Erwan_Chesnay/GodGameLPRGI.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:35:16.598Z', 'readme_url': None, 'last_activity_at': '2018-10-17T16:35:16.598Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GoldenFile-android', 'description': None, 'http_url_to_repo': 'https://gitlab.com/SinaMN75/GoldenFile-android.git', '_id': ObjectId('5bc787c32683be47187d4b4b'), 'path_with_namespace': 'SinaMN75/GoldenFile-android', 'name_with_namespace': 'Sina MohammadZadeh / GoldenFile-android', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2844783, 'parent_id': None, 'full_path': 'SinaMN75', 'path': 'SinaMN75', 'name': 'SinaMN75'}, 'id': 8915978, 'path': 'GoldenFile-android', 'web_url': 'https://gitlab.com/SinaMN75/GoldenFile-android', 'ssh_url_to_repo': 'git@gitlab.com:SinaMN75/GoldenFile-android.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:34:48.307Z', 'readme_url': 'https://gitlab.com/Sharjeel-Khan/gorn-coq/blob/master/README.md', 'last_activity_at': '2018-10-17T16:34:48.307Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gorn-coq', 'description': 'Deadlock avoidance on using futures in shared memory. The project includes the formalization of a trace language and results on a policy on safe joins (through a notion of known tasks) and we show that data-race-freedom implies deadlock freedom.', 'http_url_to_repo': 'https://gitlab.com/Sharjeel-Khan/gorn-coq.git', '_id': ObjectId('5bc787c32683be47187d4b4c'), 'path_with_namespace': 'Sharjeel-Khan/gorn-coq', 'name_with_namespace': 'Sharjeel Khan / gorn-coq', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1866785, 'parent_id': None, 'full_path': 'Sharjeel-Khan', 'path': 'Sharjeel-Khan', 'name': 'Sharjeel-Khan'}, 'id': 8915970, 'path': 'gorn-coq', 'web_url': 'https://gitlab.com/Sharjeel-Khan/gorn-coq', 'ssh_url_to_repo': 'git@gitlab.com:Sharjeel-Khan/gorn-coq.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:33:38.989Z', 'readme_url': 'https://gitlab.com/reciclanet/gitlab-transfer/blob/master/README.md', 'last_activity_at': '2018-10-17T16:33:38.989Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gitlab-transfer', 'description': "transfer reciclanet's github repos to new account in gitlab", 'http_url_to_repo': 'https://gitlab.com/reciclanet/gitlab-transfer.git', '_id': ObjectId('5bc787c32683be47187d4b4d'), 'path_with_namespace': 'reciclanet/gitlab-transfer', 'name_with_namespace': 'Reciclanet Asociacion Educativa / gitlab-transfer', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2811512, 'parent_id': None, 'full_path': 'reciclanet', 'path': 'reciclanet', 'name': 'reciclanet'}, 'id': 8915943, 'path': 'gitlab-transfer', 'web_url': 'https://gitlab.com/reciclanet/gitlab-transfer', 'ssh_url_to_repo': 'git@gitlab.com:reciclanet/gitlab-transfer.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:27:18.820Z', 'readme_url': 'https://gitlab.com/mprasil/gitlab-ce/blob/master/README.md', 'last_activity_at': '2018-10-17T16:27:18.820Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab Community Edition', 'description': 'GitLab Community Edition (CE) is an open source end-to-end software development platform with built-in version control, issue tracking, code review, CI/CD, and more. Self-host GitLab CE on your own servers, in a container, or on a cloud provider.', 'http_url_to_repo': 'https://gitlab.com/mprasil/gitlab-ce.git', '_id': ObjectId('5bc787c42683be47187d4b4e'), 'path_with_namespace': 'mprasil/gitlab-ce', 'name_with_namespace': 'Miroslav Prasil / GitLab Community Edition', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8915854/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 2212705, 'parent_id': None, 'full_path': 'mprasil', 'path': 'mprasil', 'name': 'mprasil'}, 'id': 8915854, 'path': 'gitlab-ce', 'web_url': 'https://gitlab.com/mprasil/gitlab-ce', 'ssh_url_to_repo': 'git@gitlab.com:mprasil/gitlab-ce.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T15:24:49.938Z', 'readme_url': 'https://gitlab.com/bright68/git-training/blob/master/README.md', 'last_activity_at': '2018-10-17T15:24:49.938Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'git-training', 'description': '', 'http_url_to_repo': 'https://gitlab.com/bright68/git-training.git', '_id': ObjectId('5bc787c82683be47187d4b4f'), 'path_with_namespace': 'bright68/git-training', 'name_with_namespace': 'The Bright Company / git-training', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3157970, 'parent_id': None, 'full_path': 'bright68', 'path': 'bright68', 'name': 'bright68'}, 'id': 8914979, 'path': 'git-training', 'web_url': 'https://gitlab.com/bright68/git-training', 'ssh_url_to_repo': 'git@gitlab.com:bright68/git-training.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T15:13:43.958Z', 'readme_url': None, 'last_activity_at': '2018-10-17T16:38:15.661Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gradle-demo', 'description': '', 'http_url_to_repo': 'https://gitlab.com/dbmizrahi/gradle-demo.git', '_id': ObjectId('5bc787c92683be47187d4b50'), 'path_with_namespace': 'dbmizrahi/gradle-demo', 'name_with_namespace': 'David Mizrahi / gradle-demo', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3826522, 'parent_id': None, 'full_path': 'dbmizrahi', 'path': 'dbmizrahi', 'name': 'dbmizrahi'}, 'id': 8914803, 'path': 'gradle-demo', 'web_url': 'https://gitlab.com/dbmizrahi/gradle-demo', 'ssh_url_to_repo': 'git@gitlab.com:dbmizrahi/gradle-demo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T15:09:19.885Z', 'readme_url': 'https://gitlab.com/grealish/gitlab-ce/blob/master/README.md', 'last_activity_at': '2018-10-17T15:09:19.885Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab Community Edition', 'description': 'GitLab Community Edition (CE) is an open source end-to-end software development platform with built-in version control, issue tracking, code review, CI/CD, and more. Self-host GitLab CE on your own servers, in a container, or on a cloud provider.', 'http_url_to_repo': 'https://gitlab.com/grealish/gitlab-ce.git', '_id': ObjectId('5bc787c92683be47187d4b51'), 'path_with_namespace': 'grealish/gitlab-ce', 'name_with_namespace': 'Darragh Grealish / GitLab Community Edition', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8914726/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 24715, 'parent_id': None, 'full_path': 'grealish', 'path': 'grealish', 'name': 'grealish'}, 'id': 8914726, 'path': 'gitlab-ce', 'web_url': 'https://gitlab.com/grealish/gitlab-ce', 'ssh_url_to_repo': 'git@gitlab.com:grealish/gitlab-ce.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:56:24.530Z', 'readme_url': 'https://gitlab.com/doron1803/gitlabtesting/blob/master/README.md', 'last_activity_at': '2018-10-17T16:07:02.699Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLabTesting', 'description': '', 'http_url_to_repo': 'https://gitlab.com/doron1803/gitlabtesting.git', '_id': ObjectId('5bc787c92683be47187d4b52'), 'path_with_namespace': 'doron1803/gitlabtesting', 'name_with_namespace': 'Doron Segev / GitLabTesting', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3819847, 'parent_id': None, 'full_path': 'doron1803', 'path': 'doron1803', 'name': 'doron1803'}, 'id': 8914466, 'path': 'gitlabtesting', 'web_url': 'https://gitlab.com/doron1803/gitlabtesting', 'ssh_url_to_repo': 'git@gitlab.com:doron1803/gitlabtesting.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:23:41.211Z', 'readme_url': None, 'last_activity_at': '2018-10-17T14:23:41.211Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'genetic-algorithm-dojo', 'description': '', 'http_url_to_repo': 'https://gitlab.com/adjl/genetic-algorithm-dojo.git', '_id': ObjectId('5bc787ce2683be47187d4b53'), 'path_with_namespace': 'adjl/genetic-algorithm-dojo', 'name_with_namespace': 'Adei Josol / genetic-algorithm-dojo', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3219514, 'parent_id': None, 'full_path': 'adjl', 'path': 'adjl', 'name': 'adjl'}, 'id': 8913881, 'path': 'genetic-algorithm-dojo', 'web_url': 'https://gitlab.com/adjl/genetic-algorithm-dojo', 'ssh_url_to_repo': 'git@gitlab.com:adjl/genetic-algorithm-dojo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:13:36.129Z', 'readme_url': None, 'last_activity_at': '2018-10-17T14:13:36.129Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Game Theory Workshop - report', 'description': 'Report for workshop on Game Theory from ENS Cachan MPRI course.', 'http_url_to_repo': 'https://gitlab.com/LiMeDa/game-theory-report.git', '_id': ObjectId('5bc787ce2683be47187d4b54'), 'path_with_namespace': 'LiMeDa/game-theory-report', 'name_with_namespace': 'LI / Game Theory Workshop - report', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3825426, 'parent_id': None, 'full_path': 'LiMeDa', 'path': 'LiMeDa', 'name': 'LiMeDa'}, 'id': 8913699, 'path': 'game-theory-report', 'web_url': 'https://gitlab.com/LiMeDa/game-theory-report', 'ssh_url_to_repo': 'git@gitlab.com:LiMeDa/game-theory-report.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:12:07.219Z', 'readme_url': 'https://gitlab.com/UbikBSD/ServerSide/gamerankd/blob/master/README.md', 'last_activity_at': '2018-10-17T14:12:07.219Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gamerankd', 'description': 'Game rank server can support real time update, download rank page and get user rank', 'http_url_to_repo': 'https://gitlab.com/UbikBSD/ServerSide/gamerankd.git', '_id': ObjectId('5bc787cf2683be47187d4b55'), 'path_with_namespace': 'UbikBSD/ServerSide/gamerankd', 'name_with_namespace': 'UbikBSD / ServerSide / gamerankd', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3505285, 'parent_id': 3014851, 'full_path': 'UbikBSD/ServerSide', 'path': 'ServerSide', 'name': 'ServerSide'}, 'id': 8913648, 'path': 'gamerankd', 'web_url': 'https://gitlab.com/UbikBSD/ServerSide/gamerankd', 'ssh_url_to_repo': 'git@gitlab.com:UbikBSD/ServerSide/gamerankd.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T13:38:09.142Z', 'readme_url': 'https://gitlab.com/FrankOuyang/gitlab/blob/11-3-stable-zh/README.md', 'last_activity_at': '2018-10-17T13:38:09.142Z', 'tag_list': [], 'default_branch': '11-3-stable-zh', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab 中文社区版', 'description': '(延续Larry Li的8-8-zh中文版本 gitlab.com/larryli/gitlab 进行更新)', 'http_url_to_repo': 'https://gitlab.com/FrankOuyang/gitlab.git', '_id': ObjectId('5bc787d32683be47187d4b56'), 'path_with_namespace': 'FrankOuyang/gitlab', 'name_with_namespace': 'FrankOuyang / GitLab 中文社区版', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 599482, 'parent_id': None, 'full_path': 'FrankOuyang', 'path': 'FrankOuyang', 'name': 'FrankOuyang'}, 'id': 8913066, 'path': 'gitlab', 'web_url': 'https://gitlab.com/FrankOuyang/gitlab', 'ssh_url_to_repo': 'git@gitlab.com:FrankOuyang/gitlab.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T12:48:09.520Z', 'readme_url': 'https://gitlab.com/reprazent/gitaly-proto/blob/master/README.md', 'last_activity_at': '2018-10-17T12:48:09.520Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gitaly-proto', 'description': 'gRPC protocol definitions for https://gitlab.com/gitlab-org/gitaly', 'http_url_to_repo': 'https://gitlab.com/reprazent/gitaly-proto.git', '_id': ObjectId('5bc787d92683be47187d4b57'), 'path_with_namespace': 'reprazent/gitaly-proto', 'name_with_namespace': 'Bob Van Landuyt / gitaly-proto', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 202326, 'parent_id': None, 'full_path': 'reprazent', 'path': 'reprazent', 'name': 'reprazent'}, 'id': 8912118, 'path': 'gitaly-proto', 'web_url': 'https://gitlab.com/reprazent/gitaly-proto', 'ssh_url_to_repo': 'git@gitlab.com:reprazent/gitaly-proto.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T12:43:16.601Z', 'readme_url': 'https://gitlab.com/shanestillwell/gitlab-ce/blob/master/README.md', 'last_activity_at': '2018-10-17T12:43:16.601Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab Community Edition', 'description': 'GitLab Community Edition (CE) is an open source end-to-end software development platform with built-in version control, issue tracking, code review, CI/CD, and more. Self-host GitLab CE on your own servers, in a container, or on a cloud provider.', 'http_url_to_repo': 'https://gitlab.com/shanestillwell/gitlab-ce.git', '_id': ObjectId('5bc787d92683be47187d4b58'), 'path_with_namespace': 'shanestillwell/gitlab-ce', 'name_with_namespace': 'Shane A. Stillwell / GitLab Community Edition', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8912020/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 459372, 'parent_id': None, 'full_path': 'shanestillwell', 'path': 'shanestillwell', 'name': 'shanestillwell'}, 'id': 8912020, 'path': 'gitlab-ce', 'web_url': 'https://gitlab.com/shanestillwell/gitlab-ce', 'ssh_url_to_repo': 'git@gitlab.com:shanestillwell/gitlab-ce.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:51:15.046Z', 'readme_url': 'https://gitlab.com/ferdoush10/git-test/blob/master/README.md', 'last_activity_at': '2018-10-17T11:51:15.046Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'git-test', 'description': 'Today', 'http_url_to_repo': 'https://gitlab.com/ferdoush10/git-test.git', '_id': ObjectId('5bc787de2683be47187d4b59'), 'path_with_namespace': 'ferdoush10/git-test', 'name_with_namespace': 'Md Ferdoush Wahid / git-test', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824907, 'parent_id': None, 'full_path': 'ferdoush10', 'path': 'ferdoush10', 'name': 'ferdoush10'}, 'id': 8911151, 'path': 'git-test', 'web_url': 'https://gitlab.com/ferdoush10/git-test', 'ssh_url_to_repo': 'git@gitlab.com:ferdoush10/git-test.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:43:32.635Z', 'readme_url': 'https://gitlab.com/rollun/gitlab-ci-lesson/blob/master/README.md', 'last_activity_at': '2018-10-17T16:48:18.312Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gitlab-ci-lesson', 'description': None, 'http_url_to_repo': 'https://gitlab.com/rollun/gitlab-ci-lesson.git', '_id': ObjectId('5bc787de2683be47187d4b5a'), 'path_with_namespace': 'rollun/gitlab-ci-lesson', 'name_with_namespace': 'Rollun / gitlab-ci-lesson', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3800385, 'parent_id': None, 'full_path': 'rollun', 'path': 'rollun', 'name': 'rollun'}, 'id': 8911042, 'path': 'gitlab-ci-lesson', 'web_url': 'https://gitlab.com/rollun/gitlab-ci-lesson', 'ssh_url_to_repo': 'git@gitlab.com:rollun/gitlab-ci-lesson.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:27:12.288Z', 'readme_url': None, 'last_activity_at': '2018-10-17T11:27:12.288Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gateway-service', 'description': '', 'http_url_to_repo': 'https://gitlab.com/microservices2/gateway-service.git', '_id': ObjectId('5bc787de2683be47187d4b5b'), 'path_with_namespace': 'microservices2/gateway-service', 'name_with_namespace': 'microservices2 / gateway-service', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3818048, 'parent_id': None, 'full_path': 'microservices2', 'path': 'microservices2', 'name': 'microservices2'}, 'id': 8910769, 'path': 'gateway-service', 'web_url': 'https://gitlab.com/microservices2/gateway-service', 'ssh_url_to_repo': 'git@gitlab.com:microservices2/gateway-service.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:19:58.941Z', 'readme_url': 'https://gitlab.com/issue-reproduce/grant-access-from-request/blob/master/README.md', 'last_activity_at': '2018-10-17T11:19:58.941Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'grant-access-from-request', 'description': '', 'http_url_to_repo': 'https://gitlab.com/issue-reproduce/grant-access-from-request.git', '_id': ObjectId('5bc787df2683be47187d4b5c'), 'path_with_namespace': 'issue-reproduce/grant-access-from-request', 'name_with_namespace': 'issue-reproduce / grant-access-from-request', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 785414, 'parent_id': None, 'full_path': 'issue-reproduce', 'path': 'issue-reproduce', 'name': 'issue-reproduce'}, 'id': 8910645, 'path': 'grant-access-from-request', 'web_url': 'https://gitlab.com/issue-reproduce/grant-access-from-request', 'ssh_url_to_repo': 'git@gitlab.com:issue-reproduce/grant-access-from-request.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:15:04.982Z', 'readme_url': None, 'last_activity_at': '2018-10-17T11:15:04.982Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'goglobal_bit', 'description': '', 'http_url_to_repo': 'https://gitlab.com/lutersergei/goglobal_bit.git', '_id': ObjectId('5bc787e32683be47187d4b5d'), 'path_with_namespace': 'lutersergei/goglobal_bit', 'name_with_namespace': 'luter sergei / goglobal_bit', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3823766, 'parent_id': None, 'full_path': 'lutersergei', 'path': 'lutersergei', 'name': 'lutersergei'}, 'id': 8910571, 'path': 'goglobal_bit', 'web_url': 'https://gitlab.com/lutersergei/goglobal_bit', 'ssh_url_to_repo': 'git@gitlab.com:lutersergei/goglobal_bit.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:04:58.336Z', 'readme_url': 'https://gitlab.com/bits4fun/gitlab-oss/blob/master/README.md', 'last_activity_at': '2018-10-17T11:04:58.336Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab OSS - Ultimate or Gold for open source projects', 'description': 'GitLab Ultimate or Gold for open source projects', 'http_url_to_repo': 'https://gitlab.com/bits4fun/gitlab-oss.git', '_id': ObjectId('5bc787e32683be47187d4b5e'), 'path_with_namespace': 'bits4fun/gitlab-oss', 'name_with_namespace': 'Bits4Fun / GitLab OSS - Ultimate or Gold for open source projects', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8910064/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 1382141, 'parent_id': None, 'full_path': 'bits4fun', 'path': 'bits4fun', 'name': 'bits4fun'}, 'id': 8910064, 'path': 'gitlab-oss', 'web_url': 'https://gitlab.com/bits4fun/gitlab-oss', 'ssh_url_to_repo': 'git@gitlab.com:bits4fun/gitlab-oss.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:50:12.208Z', 'readme_url': 'https://gitlab.com/gr33nonline/GhettoVaper/blob/master/README.md', 'last_activity_at': '2018-10-17T10:50:12.208Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GhettoVaper', 'description': 'Arduino Code for a Vaping Box mod', 'http_url_to_repo': 'https://gitlab.com/gr33nonline/GhettoVaper.git', '_id': ObjectId('5bc787e42683be47187d4b5f'), 'path_with_namespace': 'gr33nonline/GhettoVaper', 'name_with_namespace': 'Green online / GhettoVaper', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824445, 'parent_id': None, 'full_path': 'gr33nonline', 'path': 'gr33nonline', 'name': 'gr33nonline'}, 'id': 8909506, 'path': 'GhettoVaper', 'web_url': 'https://gitlab.com/gr33nonline/GhettoVaper', 'ssh_url_to_repo': 'git@gitlab.com:gr33nonline/GhettoVaper.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:42:35.843Z', 'readme_url': 'https://gitlab.com/rahmanjai/GameEngineOld/blob/master/README.md', 'last_activity_at': '2018-10-17T10:42:35.843Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GameEngineOld', 'description': None, 'http_url_to_repo': 'https://gitlab.com/rahmanjai/GameEngineOld.git', '_id': ObjectId('5bc787e42683be47187d4b60'), 'path_with_namespace': 'rahmanjai/GameEngineOld', 'name_with_namespace': 'Rahman Jailani / GameEngineOld', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824401, 'parent_id': None, 'full_path': 'rahmanjai', 'path': 'rahmanjai', 'name': 'rahmanjai'}, 'id': 8909414, 'path': 'GameEngineOld', 'web_url': 'https://gitlab.com/rahmanjai/GameEngineOld', 'ssh_url_to_repo': 'git@gitlab.com:rahmanjai/GameEngineOld.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:42:35.811Z', 'readme_url': 'https://gitlab.com/rahmanjai/GameEngine/blob/master/README.md', 'last_activity_at': '2018-10-17T10:42:35.811Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GameEngine', 'description': 'Source Code dari 3D Game tutorial oleh ThinMatrix', 'http_url_to_repo': 'https://gitlab.com/rahmanjai/GameEngine.git', '_id': ObjectId('5bc787e42683be47187d4b61'), 'path_with_namespace': 'rahmanjai/GameEngine', 'name_with_namespace': 'Rahman Jailani / GameEngine', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824401, 'parent_id': None, 'full_path': 'rahmanjai', 'path': 'rahmanjai', 'name': 'rahmanjai'}, 'id': 8909413, 'path': 'GameEngine', 'web_url': 'https://gitlab.com/rahmanjai/GameEngine', 'ssh_url_to_repo': 'git@gitlab.com:rahmanjai/GameEngine.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:42:02.472Z', 'readme_url': 'https://gitlab.com/biswaz/gale-crawler/blob/master/README.md', 'last_activity_at': '2018-10-17T10:42:02.472Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Gale crawler', 'description': '', 'http_url_to_repo': 'https://gitlab.com/biswaz/gale-crawler.git', '_id': ObjectId('5bc787e52683be47187d4b62'), 'path_with_namespace': 'biswaz/gale-crawler', 'name_with_namespace': 'Biswas B / Gale crawler', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1387010, 'parent_id': None, 'full_path': 'biswaz', 'path': 'biswaz', 'name': 'biswaz'}, 'id': 8909398, 'path': 'gale-crawler', 'web_url': 'https://gitlab.com/biswaz/gale-crawler', 'ssh_url_to_repo': 'git@gitlab.com:biswaz/gale-crawler.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:19:53.769Z', 'readme_url': 'https://gitlab.com/garyshen/hexo/blob/master/README.md', 'last_activity_at': '2018-10-17T10:19:53.769Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'garyshen.gitlab.io', 'description': 'Example Hexo site using GitLab Pages: https://pages.gitlab.io/hexo', 'http_url_to_repo': 'https://gitlab.com/garyshen/hexo.git', '_id': ObjectId('5bc787e92683be47187d4b63'), 'path_with_namespace': 'garyshen/hexo', 'name_with_namespace': 'garyshen / garyshen.gitlab.io', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8909041/hexo.png', 'namespace': {'kind': 'user', 'id': 3821543, 'parent_id': None, 'full_path': 'garyshen', 'path': 'garyshen', 'name': 'garyshen'}, 'id': 8909041, 'path': 'hexo', 'web_url': 'https://gitlab.com/garyshen/hexo', 'ssh_url_to_repo': 'git@gitlab.com:garyshen/hexo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:19:47.094Z', 'readme_url': 'https://gitlab.com/amydin/golangbasic/blob/master/README.md', 'last_activity_at': '2018-10-17T10:19:47.094Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Golang Basic', 'description': '', 'http_url_to_repo': 'https://gitlab.com/amydin/golangbasic.git', '_id': ObjectId('5bc787ea2683be47187d4b64'), 'path_with_namespace': 'amydin/golangbasic', 'name_with_namespace': 'Amydin S / Golang Basic', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2302135, 'parent_id': None, 'full_path': 'amydin', 'path': 'amydin', 'name': 'amydin'}, 'id': 8909038, 'path': 'golangbasic', 'web_url': 'https://gitlab.com/amydin/golangbasic', 'ssh_url_to_repo': 'git@gitlab.com:amydin/golangbasic.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:19:02.842Z', 'readme_url': 'https://gitlab.com/viasisco/gildedrose/blob/master/README.md', 'last_activity_at': '2018-10-17T10:19:02.842Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gildedrose', 'description': '', 'http_url_to_repo': 'https://gitlab.com/viasisco/gildedrose.git', '_id': ObjectId('5bc787ea2683be47187d4b65'), 'path_with_namespace': 'viasisco/gildedrose', 'name_with_namespace': 'DI MARCANTONIO / gildedrose', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 986698, 'parent_id': None, 'full_path': 'viasisco', 'path': 'viasisco', 'name': 'viasisco'}, 'id': 8909023, 'path': 'gildedrose', 'web_url': 'https://gitlab.com/viasisco/gildedrose', 'ssh_url_to_repo': 'git@gitlab.com:viasisco/gildedrose.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:16:39.266Z', 'readme_url': 'https://gitlab.com/leogopal/GyShiDo/blob/master/README.md', 'last_activity_at': '2018-10-17T10:16:39.266Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GyShiDo', 'description': 'Getting Your Shit Done', 'http_url_to_repo': 'https://gitlab.com/leogopal/GyShiDo.git', '_id': ObjectId('5bc787ea2683be47187d4b66'), 'path_with_namespace': 'leogopal/GyShiDo', 'name_with_namespace': 'Leo Gopal / GyShiDo', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2906034, 'parent_id': None, 'full_path': 'leogopal', 'path': 'leogopal', 'name': 'leogopal'}, 'id': 8908936, 'path': 'GyShiDo', 'web_url': 'https://gitlab.com/leogopal/GyShiDo', 'ssh_url_to_repo': 'git@gitlab.com:leogopal/GyShiDo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:16:36.687Z', 'readme_url': 'https://gitlab.com/leogopal/gulp-cheatsheet/blob/master/README.md', 'last_activity_at': '2018-10-17T10:16:36.687Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gulp-cheatsheet', 'description': 'A cheatsheet for gulp.js', 'http_url_to_repo': 'https://gitlab.com/leogopal/gulp-cheatsheet.git', '_id': ObjectId('5bc787eb2683be47187d4b67'), 'path_with_namespace': 'leogopal/gulp-cheatsheet', 'name_with_namespace': 'Leo Gopal / gulp-cheatsheet', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2906034, 'parent_id': None, 'full_path': 'leogopal', 'path': 'leogopal', 'name': 'leogopal'}, 'id': 8908935, 'path': 'gulp-cheatsheet', 'web_url': 'https://gitlab.com/leogopal/gulp-cheatsheet', 'ssh_url_to_repo': 'git@gitlab.com:leogopal/gulp-cheatsheet.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:11:51.295Z', 'readme_url': None, 'last_activity_at': '2018-10-17T10:11:51.295Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'git-jest-git', 'description': '', 'http_url_to_repo': 'https://gitlab.com/Siemko/git-jest-git.git', '_id': ObjectId('5bc787ef2683be47187d4b68'), 'path_with_namespace': 'Siemko/git-jest-git', 'name_with_namespace': 'Dominik / git-jest-git', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1134740, 'parent_id': None, 'full_path': 'Siemko', 'path': 'Siemko', 'name': 'Siemko'}, 'id': 8908855, 'path': 'git-jest-git', 'web_url': 'https://gitlab.com/Siemko/git-jest-git', 'ssh_url_to_repo': 'git@gitlab.com:Siemko/git-jest-git.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:09:16.262Z', 'readme_url': None, 'last_activity_at': '2018-10-17T10:09:16.262Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'grace', 'description': ' Hoppr\'s Build-Tool/Pkg-Man. "grace [pkg,doc,sys,help]" ', 'http_url_to_repo': 'https://gitlab.com/Terasform/grace.git', '_id': ObjectId('5bc787ef2683be47187d4b69'), 'path_with_namespace': 'Terasform/grace', 'name_with_namespace': ' Terasform Education-Engine. / grace', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3824136, 'parent_id': None, 'full_path': 'Terasform', 'path': 'Terasform', 'name': ' Terasform Education-Engine.'}, 'id': 8908819, 'path': 'grace', 'web_url': 'https://gitlab.com/Terasform/grace', 'ssh_url_to_repo': 'git@gitlab.com:Terasform/grace.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:00:28.239Z', 'readme_url': 'https://gitlab.com/vinit.k/guestbook/blob/master/README.md', 'last_activity_at': '2018-10-17T10:00:28.239Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GuestBook', 'description': '', 'http_url_to_repo': 'https://gitlab.com/vinit.k/guestbook.git', '_id': ObjectId('5bc787f02683be47187d4b6a'), 'path_with_namespace': 'vinit.k/guestbook', 'name_with_namespace': 'Vinit Kumar / GuestBook', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1686148, 'parent_id': None, 'full_path': 'vinit.k', 'path': 'vinit.k', 'name': 'vinit.k'}, 'id': 8908688, 'path': 'guestbook', 'web_url': 'https://gitlab.com/vinit.k/guestbook', 'ssh_url_to_repo': 'git@gitlab.com:vinit.k/guestbook.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T09:59:09.201Z', 'readme_url': 'https://gitlab.com/bolotweet/gnu-social/blob/master/README.md', 'last_activity_at': '2018-10-17T09:59:09.201Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gnu-social', 'description': '', 'http_url_to_repo': 'https://gitlab.com/bolotweet/gnu-social.git', '_id': ObjectId('5bc787f02683be47187d4b6b'), 'path_with_namespace': 'bolotweet/gnu-social', 'name_with_namespace': 'bolotweet / gnu-social', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3823903, 'parent_id': None, 'full_path': 'bolotweet', 'path': 'bolotweet', 'name': 'bolotweet'}, 'id': 8908664, 'path': 'gnu-social', 'web_url': 'https://gitlab.com/bolotweet/gnu-social', 'ssh_url_to_repo': 'git@gitlab.com:bolotweet/gnu-social.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T09:55:59.815Z', 'readme_url': 'https://gitlab.com/bolotweet/Grades/blob/master/README.md', 'last_activity_at': '2018-10-17T09:55:59.815Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Grades', 'description': '', 'http_url_to_repo': 'https://gitlab.com/bolotweet/Grades.git', '_id': ObjectId('5bc787f02683be47187d4b6c'), 'path_with_namespace': 'bolotweet/Grades', 'name_with_namespace': 'bolotweet / Grades', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3823903, 'parent_id': None, 'full_path': 'bolotweet', 'path': 'bolotweet', 'name': 'bolotweet'}, 'id': 8908610, 'path': 'Grades', 'web_url': 'https://gitlab.com/bolotweet/Grades', 'ssh_url_to_repo': 'git@gitlab.com:bolotweet/Grades.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T09:39:15.242Z', 'readme_url': 'https://gitlab.com/_Guinome/graphql-workshop/blob/master/README.md', 'last_activity_at': '2018-10-17T09:39:15.242Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'graphql-workshop', 'description': '', 'http_url_to_repo': 'https://gitlab.com/_Guinome/graphql-workshop.git', '_id': ObjectId('5bc787f12683be47187d4b6d'), 'path_with_namespace': '_Guinome/graphql-workshop', 'name_with_namespace': 'Guillaume Orsoni / graphql-workshop', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3569910, 'parent_id': None, 'full_path': '_Guinome', 'path': '_Guinome', 'name': '_Guinome'}, 'id': 8908313, 'path': 'graphql-workshop', 'web_url': 'https://gitlab.com/_Guinome/graphql-workshop', 'ssh_url_to_repo': 'git@gitlab.com:_Guinome/graphql-workshop.git'}

# %%
import sys
import re
import pymongo
import json
import time
import datetime
import requests
from bs4 import BeautifulSoup

dbname = "fdac18mp2" #please use this database
collname = "glprj_trahman4_coll" #please modify so you store data in your collection
my_char = 'g'

# beginning page index
begin = "1"
client = pymongo.MongoClient()

db = client[dbname]
coll = db[collname]


gitlab_url = "https://gitlab.com/api/v4/projects?archived=false&membership=false&order_by=created_at&owned=false&page=" + begin + \
    "&per_page=99&simple=false&sort=desc&starred=false&statistics=false&with_custom_attributes=false&with_issues_enabled=false&with_merge_requests_enabled=false"

gleft = 20

source_url = "https://sourceforge.net/directory/?q=" + my_char + "&sort=name&page="
rest_url = "https://sourceforge.net/rest/p/"

header = {'per_page': 99}

# check remaining query chances for rate-limit restriction
def wait(left):
    global header
    while (left < 20):
        l = requests.get('https://gitlab.com/api/v4/projects', headers=header)
        if (l.ok):
            left = int(l.headers.get('RateLimit-Remaining'))
        time .sleep(60)
    return left

def project_exists(url):
    r = requests.get(url)
    if r.status_code == 200:
        return True
    return False

def get_source(url, coll, rest):
    page = 1
    project_count = 0
    while True:
        resp = requests.get(url + str(page))
        text = resp.text
        soup = BeautifulSoup(text, 'html.parser')
        if re.search('No results found.', soup.get_text()):
            return

        for link in soup.find_all(class_="project-icon", href=True):
            name = re.findall('/projects/([A-Za-z0-9\-]*)', link.get('href'))
            name = name[0] if name else None
            if name is not None and name.lower().startswith(my_char):
                resp = requests.get(rest + name)
                if resp.status_code == 200:
                    info = json.loads(resp.text)
                    info['forge'] = 'sourceforge'
                    coll.insert_one(info)
                    project_count += 1
                    if project_count >= 50:
                        return
        page += 1
    return

# send queries and extract urls 
def get_gitlab(url, coll):

    global gleft
    global header
    global bginnum
    gleft = wait(gleft)
    values = []
    size = 0
    project_count = 0

    try:
        r = requests .get(url, headers=header)
        time .sleep(0.5)
        # got blocked
        if r.status_code == 403:
            return "got blocked", str(bginnum)
        if (r.ok):

            gleft = int(r.headers.get('RateLimit-Remaining'))
            lll = r.headers.get('Link')
            t = r.text
            array = json.loads(t)
            
            for el in array:
                if el['name'].lower().startswith(my_char):
                    if project_exists(el['http_url_to_repo']):
                        project_count += 1
                        el['forge'] = 'gitlab'
                        coll.insert_one(el)
                        if project_count >= 50:
                            return
            
            #next page
            while ('; rel="next"' in lll):
                gleft = int(r.headers.get('RateLimit-Remaining'))
                gleft = wait(gleft)
                # extract next page url
                ll = lll.replace(';', ',').split(',')
                url = ll[ll.index(' rel="next"') -
                         1].replace('<', '').replace('>', '').lstrip()
             
                try:
                    r = requests .get(url, headers=header)
                    if r.status_code == 403:
                        return "got blocked", str(bginnum)
                    if (r.ok):
                        lll = r.headers.get('Link')
                        t = r.text
                        array1 = json.loads(t)
                        for el in array1:
                            if el['name'].lower().startswith(my_char):
                                if project_exists(el['http_url_to_repo']):
                                    project_count += 1
                                    el['forge'] = 'gitlab'
                                    coll.insert_one(el)
                                    if project_count >= 50:
                                        return
                    else:
                        sys.stderr.write("url can not found:\n" + url + '\n')
                        return 
                except requests.exceptions.ConnectionError:
                    sys.stderr.write('could not get ' + url + '\n')
            
        else:
            sys.stderr.write("url can not found:\n" + url + '\n')
            return

    except requests.exceptions.ConnectionError:
        sys.stderr.write('could not get ' + url + '\n')
    except Exception as e:
        sys.stderr.write(url + ';' + str(e) + '\n')
        
#start retrieving        
get_gitlab(gitlab_url,coll)
get_source(source_url, coll, rest_url)
#print collected data
for doc in coll.find({}):
    print(doc)
# Out:
# {'forks_count': 0, 'created_at': '2018-10-17T19:02:00.230Z', 'readme_url': None, 'last_activity_at': '2018-10-17T19:02:00.230Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Game_Website', 'description': 'Check data from games, HTML, MYSQL, PHP, jscript', 'http_url_to_repo': 'https://gitlab.com/michaelmercier/game_website.git', '_id': ObjectId('5bc788a42683be47187d4b71'), 'path_with_namespace': 'michaelmercier/game_website', 'name_with_namespace': 'mike / Game_Website', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 958316, 'parent_id': None, 'full_path': 'michaelmercier', 'path': 'michaelmercier', 'name': 'michaelmercier'}, 'id': 8918171, 'path': 'game_website', 'web_url': 'https://gitlab.com/michaelmercier/game_website', 'ssh_url_to_repo': 'git@gitlab.com:michaelmercier/game_website.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T18:57:44.620Z', 'readme_url': None, 'last_activity_at': '2018-10-17T18:57:44.620Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'g2-saltmaster-states', 'description': '', 'http_url_to_repo': 'https://gitlab.com/napindc/g2-saltmaster-states.git', '_id': ObjectId('5bc788a42683be47187d4b72'), 'path_with_namespace': 'napindc/g2-saltmaster-states', 'name_with_namespace': 'Mike / g2-saltmaster-states', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1960225, 'parent_id': None, 'full_path': 'napindc', 'path': 'napindc', 'name': 'napindc'}, 'id': 8918107, 'path': 'g2-saltmaster-states', 'web_url': 'https://gitlab.com/napindc/g2-saltmaster-states', 'ssh_url_to_repo': 'git@gitlab.com:napindc/g2-saltmaster-states.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T18:38:35.760Z', 'readme_url': None, 'last_activity_at': '2018-10-17T18:38:35.760Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GestureTest', 'description': None, 'http_url_to_repo': 'https://gitlab.com/FuadYoussef/GestureTest.git', '_id': ObjectId('5bc788a52683be47187d4b73'), 'path_with_namespace': 'FuadYoussef/GestureTest', 'name_with_namespace': 'Fuad Youssef / GestureTest', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3827745, 'parent_id': None, 'full_path': 'FuadYoussef', 'path': 'FuadYoussef', 'name': 'FuadYoussef'}, 'id': 8917861, 'path': 'GestureTest', 'web_url': 'https://gitlab.com/FuadYoussef/GestureTest', 'ssh_url_to_repo': 'git@gitlab.com:FuadYoussef/GestureTest.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T18:23:54.668Z', 'readme_url': 'https://gitlab.com/andrewlader/go-gently/blob/master/README.md', 'last_activity_at': '2018-10-17T18:23:54.668Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'go-gently', 'description': 'The Go-Gently service is a Go language package to enable other Go services to gently shutdown when they receive a SIGTERM, SIGINT or SIGQUIT signal.', 'http_url_to_repo': 'https://gitlab.com/andrewlader/go-gently.git', '_id': ObjectId('5bc788a52683be47187d4b74'), 'path_with_namespace': 'andrewlader/go-gently', 'name_with_namespace': 'Andrew Lader / go-gently', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1900987, 'parent_id': None, 'full_path': 'andrewlader', 'path': 'andrewlader', 'name': 'andrewlader'}, 'id': 8917693, 'path': 'go-gently', 'web_url': 'https://gitlab.com/andrewlader/go-gently', 'ssh_url_to_repo': 'git@gitlab.com:andrewlader/go-gently.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:18:34.002Z', 'readme_url': 'https://gitlab.com/ricardo_jr37/gti_of/blob/master/README.md', 'last_activity_at': '2018-10-17T17:18:34.002Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gti_of', 'description': '', 'http_url_to_repo': 'https://gitlab.com/ricardo_jr37/gti_of.git', '_id': ObjectId('5bc788aa2683be47187d4b75'), 'path_with_namespace': 'ricardo_jr37/gti_of', 'name_with_namespace': 'Antonio Ricardo Coelho Alcantara Junior / gti_of', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3512488, 'parent_id': None, 'full_path': 'ricardo_jr37', 'path': 'ricardo_jr37', 'name': 'ricardo_jr37'}, 'id': 8916779, 'path': 'gti_of', 'web_url': 'https://gitlab.com/ricardo_jr37/gti_of', 'ssh_url_to_repo': 'git@gitlab.com:ricardo_jr37/gti_of.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.864Z', 'readme_url': 'https://gitlab.com/tycho01/gym/blob/master/README.rst', 'last_activity_at': '2018-10-17T17:02:42.864Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gym', 'description': 'A toolkit for developing and comparing reinforcement learning algorithms.', 'http_url_to_repo': 'https://gitlab.com/tycho01/gym.git', '_id': ObjectId('5bc788b32683be47187d4b76'), 'path_with_namespace': 'tycho01/gym', 'name_with_namespace': 'Tycho Grouwstra / gym', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916456, 'path': 'gym', 'web_url': 'https://gitlab.com/tycho01/gym', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/gym.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.760Z', 'readme_url': 'https://gitlab.com/tycho01/gs-spring-boot/blob/master/README.adoc', 'last_activity_at': '2018-10-17T17:02:42.760Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gs-spring-boot', 'description': 'Building an Application with Spring Boot :: Learn how to build an application with minimal configuration.', 'http_url_to_repo': 'https://gitlab.com/tycho01/gs-spring-boot.git', '_id': ObjectId('5bc788b42683be47187d4b77'), 'path_with_namespace': 'tycho01/gs-spring-boot', 'name_with_namespace': 'Tycho Grouwstra / gs-spring-boot', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916455, 'path': 'gs-spring-boot', 'web_url': 'https://gitlab.com/tycho01/gs-spring-boot', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/gs-spring-boot.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.658Z', 'readme_url': 'https://gitlab.com/tycho01/gs-accessing-data-jpa/blob/master/README.adoc', 'last_activity_at': '2018-10-17T17:02:42.658Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gs-accessing-data-jpa', 'description': 'Accessing Data with JPA :: Learn how to work with JPA data persistence using Spring Data JPA.', 'http_url_to_repo': 'https://gitlab.com/tycho01/gs-accessing-data-jpa.git', '_id': ObjectId('5bc788b42683be47187d4b78'), 'path_with_namespace': 'tycho01/gs-accessing-data-jpa', 'name_with_namespace': 'Tycho Grouwstra / gs-accessing-data-jpa', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916454, 'path': 'gs-accessing-data-jpa', 'web_url': 'https://gitlab.com/tycho01/gs-accessing-data-jpa', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/gs-accessing-data-jpa.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.547Z', 'readme_url': 'https://gitlab.com/tycho01/google-taxonomy-matcher/blob/master/README.md', 'last_activity_at': '2018-10-17T17:02:42.547Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'google-taxonomy-matcher', 'description': "Matches a category of Google's Taxonomy to product that is described in any kind of text data", 'http_url_to_repo': 'https://gitlab.com/tycho01/google-taxonomy-matcher.git', '_id': ObjectId('5bc788b42683be47187d4b79'), 'path_with_namespace': 'tycho01/google-taxonomy-matcher', 'name_with_namespace': 'Tycho Grouwstra / google-taxonomy-matcher', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916453, 'path': 'google-taxonomy-matcher', 'web_url': 'https://gitlab.com/tycho01/google-taxonomy-matcher', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/google-taxonomy-matcher.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T17:02:42.436Z', 'readme_url': 'https://gitlab.com/tycho01/glossary/blob/master/README.md', 'last_activity_at': '2018-10-17T17:02:42.436Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'glossary', 'description': 'https://machinelearning.wtf/  - An online glossary of machine learning terms.', 'http_url_to_repo': 'https://gitlab.com/tycho01/glossary.git', '_id': ObjectId('5bc788b52683be47187d4b7a'), 'path_with_namespace': 'tycho01/glossary', 'name_with_namespace': 'Tycho Grouwstra / glossary', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 797239, 'parent_id': None, 'full_path': 'tycho01', 'path': 'tycho01', 'name': 'tycho01'}, 'id': 8916452, 'path': 'glossary', 'web_url': 'https://gitlab.com/tycho01/glossary', 'ssh_url_to_repo': 'git@gitlab.com:tycho01/glossary.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:59:31.310Z', 'readme_url': 'https://gitlab.com/pvbinh1985/game/blob/master/README.md', 'last_activity_at': '2018-10-17T16:59:31.310Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'game', 'description': '', 'http_url_to_repo': 'https://gitlab.com/pvbinh1985/game.git', '_id': ObjectId('5bc788b52683be47187d4b7b'), 'path_with_namespace': 'pvbinh1985/game', 'name_with_namespace': 'Phan Binh / game', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3827222, 'parent_id': None, 'full_path': 'pvbinh1985', 'path': 'pvbinh1985', 'name': 'pvbinh1985'}, 'id': 8916360, 'path': 'game', 'web_url': 'https://gitlab.com/pvbinh1985/game', 'ssh_url_to_repo': 'git@gitlab.com:pvbinh1985/game.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:46:53.400Z', 'readme_url': 'https://gitlab.com/s.v.ivko/go-course/blob/week_5/README.md', 'last_activity_at': '2018-10-17T16:46:53.400Z', 'tag_list': [], 'default_branch': 'week_5', 'forge': 'gitlab', 'star_count': 0, 'name': 'go-course', 'description': '', 'http_url_to_repo': 'https://gitlab.com/s.v.ivko/go-course.git', '_id': ObjectId('5bc788b52683be47187d4b7c'), 'path_with_namespace': 's.v.ivko/go-course', 'name_with_namespace': 'Serg Ivko / go-course', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2935159, 'parent_id': None, 'full_path': 's.v.ivko', 'path': 's.v.ivko', 'name': 's.v.ivko'}, 'id': 8916180, 'path': 'go-course', 'web_url': 'https://gitlab.com/s.v.ivko/go-course', 'ssh_url_to_repo': 'git@gitlab.com:s.v.ivko/go-course.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:46:38.009Z', 'readme_url': 'https://gitlab.com/dieggsy/geiser/blob/master/README.org', 'last_activity_at': '2018-10-17T16:46:38.009Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'geiser', 'description': 'emacs and scheme talk to each other', 'http_url_to_repo': 'https://gitlab.com/dieggsy/geiser.git', '_id': ObjectId('5bc788b62683be47187d4b7d'), 'path_with_namespace': 'dieggsy/geiser', 'name_with_namespace': 'diego / geiser', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 761463, 'parent_id': None, 'full_path': 'dieggsy', 'path': 'dieggsy', 'name': 'dieggsy'}, 'id': 8916177, 'path': 'geiser', 'web_url': 'https://gitlab.com/dieggsy/geiser', 'ssh_url_to_repo': 'git@gitlab.com:dieggsy/geiser.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:42:34.623Z', 'readme_url': 'https://gitlab.com/Erwan_Chesnay/GodGameLPRGI/blob/master/README.md', 'last_activity_at': '2018-10-17T16:42:34.623Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GodGameLPRGI', 'description': "C'est un projet trop bien (mais dur)", 'http_url_to_repo': 'https://gitlab.com/Erwan_Chesnay/GodGameLPRGI.git', '_id': ObjectId('5bc788b62683be47187d4b7e'), 'path_with_namespace': 'Erwan_Chesnay/GodGameLPRGI', 'name_with_namespace': 'Erwan Chesnay / GodGameLPRGI', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1961416, 'parent_id': None, 'full_path': 'Erwan_Chesnay', 'path': 'Erwan_Chesnay', 'name': 'Erwan_Chesnay'}, 'id': 8916106, 'path': 'GodGameLPRGI', 'web_url': 'https://gitlab.com/Erwan_Chesnay/GodGameLPRGI', 'ssh_url_to_repo': 'git@gitlab.com:Erwan_Chesnay/GodGameLPRGI.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:35:16.598Z', 'readme_url': None, 'last_activity_at': '2018-10-17T16:35:16.598Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GoldenFile-android', 'description': None, 'http_url_to_repo': 'https://gitlab.com/SinaMN75/GoldenFile-android.git', '_id': ObjectId('5bc788bb2683be47187d4b7f'), 'path_with_namespace': 'SinaMN75/GoldenFile-android', 'name_with_namespace': 'Sina MohammadZadeh / GoldenFile-android', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2844783, 'parent_id': None, 'full_path': 'SinaMN75', 'path': 'SinaMN75', 'name': 'SinaMN75'}, 'id': 8915978, 'path': 'GoldenFile-android', 'web_url': 'https://gitlab.com/SinaMN75/GoldenFile-android', 'ssh_url_to_repo': 'git@gitlab.com:SinaMN75/GoldenFile-android.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:34:48.307Z', 'readme_url': 'https://gitlab.com/Sharjeel-Khan/gorn-coq/blob/master/README.md', 'last_activity_at': '2018-10-17T16:34:48.307Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gorn-coq', 'description': 'Deadlock avoidance on using futures in shared memory. The project includes the formalization of a trace language and results on a policy on safe joins (through a notion of known tasks) and we show that data-race-freedom implies deadlock freedom.', 'http_url_to_repo': 'https://gitlab.com/Sharjeel-Khan/gorn-coq.git', '_id': ObjectId('5bc788bb2683be47187d4b80'), 'path_with_namespace': 'Sharjeel-Khan/gorn-coq', 'name_with_namespace': 'Sharjeel Khan / gorn-coq', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1866785, 'parent_id': None, 'full_path': 'Sharjeel-Khan', 'path': 'Sharjeel-Khan', 'name': 'Sharjeel-Khan'}, 'id': 8915970, 'path': 'gorn-coq', 'web_url': 'https://gitlab.com/Sharjeel-Khan/gorn-coq', 'ssh_url_to_repo': 'git@gitlab.com:Sharjeel-Khan/gorn-coq.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:33:38.989Z', 'readme_url': 'https://gitlab.com/reciclanet/gitlab-transfer/blob/master/README.md', 'last_activity_at': '2018-10-17T16:33:38.989Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gitlab-transfer', 'description': "transfer reciclanet's github repos to new account in gitlab", 'http_url_to_repo': 'https://gitlab.com/reciclanet/gitlab-transfer.git', '_id': ObjectId('5bc788bb2683be47187d4b81'), 'path_with_namespace': 'reciclanet/gitlab-transfer', 'name_with_namespace': 'Reciclanet Asociacion Educativa / gitlab-transfer', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2811512, 'parent_id': None, 'full_path': 'reciclanet', 'path': 'reciclanet', 'name': 'reciclanet'}, 'id': 8915943, 'path': 'gitlab-transfer', 'web_url': 'https://gitlab.com/reciclanet/gitlab-transfer', 'ssh_url_to_repo': 'git@gitlab.com:reciclanet/gitlab-transfer.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T16:27:18.820Z', 'readme_url': 'https://gitlab.com/mprasil/gitlab-ce/blob/master/README.md', 'last_activity_at': '2018-10-17T16:27:18.820Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab Community Edition', 'description': 'GitLab Community Edition (CE) is an open source end-to-end software development platform with built-in version control, issue tracking, code review, CI/CD, and more. Self-host GitLab CE on your own servers, in a container, or on a cloud provider.', 'http_url_to_repo': 'https://gitlab.com/mprasil/gitlab-ce.git', '_id': ObjectId('5bc788bc2683be47187d4b82'), 'path_with_namespace': 'mprasil/gitlab-ce', 'name_with_namespace': 'Miroslav Prasil / GitLab Community Edition', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8915854/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 2212705, 'parent_id': None, 'full_path': 'mprasil', 'path': 'mprasil', 'name': 'mprasil'}, 'id': 8915854, 'path': 'gitlab-ce', 'web_url': 'https://gitlab.com/mprasil/gitlab-ce', 'ssh_url_to_repo': 'git@gitlab.com:mprasil/gitlab-ce.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T15:24:49.938Z', 'readme_url': 'https://gitlab.com/bright68/git-training/blob/master/README.md', 'last_activity_at': '2018-10-17T15:24:49.938Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'git-training', 'description': '', 'http_url_to_repo': 'https://gitlab.com/bright68/git-training.git', '_id': ObjectId('5bc788c12683be47187d4b83'), 'path_with_namespace': 'bright68/git-training', 'name_with_namespace': 'The Bright Company / git-training', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3157970, 'parent_id': None, 'full_path': 'bright68', 'path': 'bright68', 'name': 'bright68'}, 'id': 8914979, 'path': 'git-training', 'web_url': 'https://gitlab.com/bright68/git-training', 'ssh_url_to_repo': 'git@gitlab.com:bright68/git-training.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T15:13:43.958Z', 'readme_url': None, 'last_activity_at': '2018-10-17T16:38:15.661Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gradle-demo', 'description': '', 'http_url_to_repo': 'https://gitlab.com/dbmizrahi/gradle-demo.git', '_id': ObjectId('5bc788c12683be47187d4b84'), 'path_with_namespace': 'dbmizrahi/gradle-demo', 'name_with_namespace': 'David Mizrahi / gradle-demo', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3826522, 'parent_id': None, 'full_path': 'dbmizrahi', 'path': 'dbmizrahi', 'name': 'dbmizrahi'}, 'id': 8914803, 'path': 'gradle-demo', 'web_url': 'https://gitlab.com/dbmizrahi/gradle-demo', 'ssh_url_to_repo': 'git@gitlab.com:dbmizrahi/gradle-demo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T15:09:19.885Z', 'readme_url': 'https://gitlab.com/grealish/gitlab-ce/blob/master/README.md', 'last_activity_at': '2018-10-17T15:09:19.885Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab Community Edition', 'description': 'GitLab Community Edition (CE) is an open source end-to-end software development platform with built-in version control, issue tracking, code review, CI/CD, and more. Self-host GitLab CE on your own servers, in a container, or on a cloud provider.', 'http_url_to_repo': 'https://gitlab.com/grealish/gitlab-ce.git', '_id': ObjectId('5bc788c22683be47187d4b85'), 'path_with_namespace': 'grealish/gitlab-ce', 'name_with_namespace': 'Darragh Grealish / GitLab Community Edition', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8914726/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 24715, 'parent_id': None, 'full_path': 'grealish', 'path': 'grealish', 'name': 'grealish'}, 'id': 8914726, 'path': 'gitlab-ce', 'web_url': 'https://gitlab.com/grealish/gitlab-ce', 'ssh_url_to_repo': 'git@gitlab.com:grealish/gitlab-ce.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:56:24.530Z', 'readme_url': 'https://gitlab.com/doron1803/gitlabtesting/blob/master/README.md', 'last_activity_at': '2018-10-17T16:07:02.699Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLabTesting', 'description': '', 'http_url_to_repo': 'https://gitlab.com/doron1803/gitlabtesting.git', '_id': ObjectId('5bc788c22683be47187d4b86'), 'path_with_namespace': 'doron1803/gitlabtesting', 'name_with_namespace': 'Doron Segev / GitLabTesting', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3819847, 'parent_id': None, 'full_path': 'doron1803', 'path': 'doron1803', 'name': 'doron1803'}, 'id': 8914466, 'path': 'gitlabtesting', 'web_url': 'https://gitlab.com/doron1803/gitlabtesting', 'ssh_url_to_repo': 'git@gitlab.com:doron1803/gitlabtesting.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:23:41.211Z', 'readme_url': None, 'last_activity_at': '2018-10-17T14:23:41.211Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'genetic-algorithm-dojo', 'description': '', 'http_url_to_repo': 'https://gitlab.com/adjl/genetic-algorithm-dojo.git', '_id': ObjectId('5bc788c72683be47187d4b87'), 'path_with_namespace': 'adjl/genetic-algorithm-dojo', 'name_with_namespace': 'Adei Josol / genetic-algorithm-dojo', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3219514, 'parent_id': None, 'full_path': 'adjl', 'path': 'adjl', 'name': 'adjl'}, 'id': 8913881, 'path': 'genetic-algorithm-dojo', 'web_url': 'https://gitlab.com/adjl/genetic-algorithm-dojo', 'ssh_url_to_repo': 'git@gitlab.com:adjl/genetic-algorithm-dojo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:13:36.129Z', 'readme_url': None, 'last_activity_at': '2018-10-17T14:13:36.129Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Game Theory Workshop - report', 'description': 'Report for workshop on Game Theory from ENS Cachan MPRI course.', 'http_url_to_repo': 'https://gitlab.com/LiMeDa/game-theory-report.git', '_id': ObjectId('5bc788c72683be47187d4b88'), 'path_with_namespace': 'LiMeDa/game-theory-report', 'name_with_namespace': 'LI / Game Theory Workshop - report', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3825426, 'parent_id': None, 'full_path': 'LiMeDa', 'path': 'LiMeDa', 'name': 'LiMeDa'}, 'id': 8913699, 'path': 'game-theory-report', 'web_url': 'https://gitlab.com/LiMeDa/game-theory-report', 'ssh_url_to_repo': 'git@gitlab.com:LiMeDa/game-theory-report.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T14:12:07.219Z', 'readme_url': 'https://gitlab.com/UbikBSD/ServerSide/gamerankd/blob/master/README.md', 'last_activity_at': '2018-10-17T14:12:07.219Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gamerankd', 'description': 'Game rank server can support real time update, download rank page and get user rank', 'http_url_to_repo': 'https://gitlab.com/UbikBSD/ServerSide/gamerankd.git', '_id': ObjectId('5bc788cc2683be47187d4b89'), 'path_with_namespace': 'UbikBSD/ServerSide/gamerankd', 'name_with_namespace': 'UbikBSD / ServerSide / gamerankd', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3505285, 'parent_id': 3014851, 'full_path': 'UbikBSD/ServerSide', 'path': 'ServerSide', 'name': 'ServerSide'}, 'id': 8913648, 'path': 'gamerankd', 'web_url': 'https://gitlab.com/UbikBSD/ServerSide/gamerankd', 'ssh_url_to_repo': 'git@gitlab.com:UbikBSD/ServerSide/gamerankd.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T13:38:09.142Z', 'readme_url': 'https://gitlab.com/FrankOuyang/gitlab/blob/11-3-stable-zh/README.md', 'last_activity_at': '2018-10-17T13:38:09.142Z', 'tag_list': [], 'default_branch': '11-3-stable-zh', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab 中文社区版', 'description': '(延续Larry Li的8-8-zh中文版本 gitlab.com/larryli/gitlab 进行更新)', 'http_url_to_repo': 'https://gitlab.com/FrankOuyang/gitlab.git', '_id': ObjectId('5bc788d52683be47187d4b8a'), 'path_with_namespace': 'FrankOuyang/gitlab', 'name_with_namespace': 'FrankOuyang / GitLab 中文社区版', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 599482, 'parent_id': None, 'full_path': 'FrankOuyang', 'path': 'FrankOuyang', 'name': 'FrankOuyang'}, 'id': 8913066, 'path': 'gitlab', 'web_url': 'https://gitlab.com/FrankOuyang/gitlab', 'ssh_url_to_repo': 'git@gitlab.com:FrankOuyang/gitlab.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T12:48:09.520Z', 'readme_url': 'https://gitlab.com/reprazent/gitaly-proto/blob/master/README.md', 'last_activity_at': '2018-10-17T12:48:09.520Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gitaly-proto', 'description': 'gRPC protocol definitions for https://gitlab.com/gitlab-org/gitaly', 'http_url_to_repo': 'https://gitlab.com/reprazent/gitaly-proto.git', '_id': ObjectId('5bc788db2683be47187d4b8b'), 'path_with_namespace': 'reprazent/gitaly-proto', 'name_with_namespace': 'Bob Van Landuyt / gitaly-proto', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 202326, 'parent_id': None, 'full_path': 'reprazent', 'path': 'reprazent', 'name': 'reprazent'}, 'id': 8912118, 'path': 'gitaly-proto', 'web_url': 'https://gitlab.com/reprazent/gitaly-proto', 'ssh_url_to_repo': 'git@gitlab.com:reprazent/gitaly-proto.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T12:43:16.601Z', 'readme_url': 'https://gitlab.com/shanestillwell/gitlab-ce/blob/master/README.md', 'last_activity_at': '2018-10-17T12:43:16.601Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab Community Edition', 'description': 'GitLab Community Edition (CE) is an open source end-to-end software development platform with built-in version control, issue tracking, code review, CI/CD, and more. Self-host GitLab CE on your own servers, in a container, or on a cloud provider.', 'http_url_to_repo': 'https://gitlab.com/shanestillwell/gitlab-ce.git', '_id': ObjectId('5bc788df2683be47187d4b8c'), 'path_with_namespace': 'shanestillwell/gitlab-ce', 'name_with_namespace': 'Shane A. Stillwell / GitLab Community Edition', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8912020/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 459372, 'parent_id': None, 'full_path': 'shanestillwell', 'path': 'shanestillwell', 'name': 'shanestillwell'}, 'id': 8912020, 'path': 'gitlab-ce', 'web_url': 'https://gitlab.com/shanestillwell/gitlab-ce', 'ssh_url_to_repo': 'git@gitlab.com:shanestillwell/gitlab-ce.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:51:15.046Z', 'readme_url': 'https://gitlab.com/ferdoush10/git-test/blob/master/README.md', 'last_activity_at': '2018-10-17T11:51:15.046Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'git-test', 'description': 'Today', 'http_url_to_repo': 'https://gitlab.com/ferdoush10/git-test.git', '_id': ObjectId('5bc788df2683be47187d4b8d'), 'path_with_namespace': 'ferdoush10/git-test', 'name_with_namespace': 'Md Ferdoush Wahid / git-test', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824907, 'parent_id': None, 'full_path': 'ferdoush10', 'path': 'ferdoush10', 'name': 'ferdoush10'}, 'id': 8911151, 'path': 'git-test', 'web_url': 'https://gitlab.com/ferdoush10/git-test', 'ssh_url_to_repo': 'git@gitlab.com:ferdoush10/git-test.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:43:32.635Z', 'readme_url': 'https://gitlab.com/rollun/gitlab-ci-lesson/blob/master/README.md', 'last_activity_at': '2018-10-17T16:48:18.312Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gitlab-ci-lesson', 'description': None, 'http_url_to_repo': 'https://gitlab.com/rollun/gitlab-ci-lesson.git', '_id': ObjectId('5bc788e02683be47187d4b8e'), 'path_with_namespace': 'rollun/gitlab-ci-lesson', 'name_with_namespace': 'Rollun / gitlab-ci-lesson', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3800385, 'parent_id': None, 'full_path': 'rollun', 'path': 'rollun', 'name': 'rollun'}, 'id': 8911042, 'path': 'gitlab-ci-lesson', 'web_url': 'https://gitlab.com/rollun/gitlab-ci-lesson', 'ssh_url_to_repo': 'git@gitlab.com:rollun/gitlab-ci-lesson.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:27:12.288Z', 'readme_url': None, 'last_activity_at': '2018-10-17T11:27:12.288Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gateway-service', 'description': '', 'http_url_to_repo': 'https://gitlab.com/microservices2/gateway-service.git', '_id': ObjectId('5bc788e02683be47187d4b8f'), 'path_with_namespace': 'microservices2/gateway-service', 'name_with_namespace': 'microservices2 / gateway-service', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3818048, 'parent_id': None, 'full_path': 'microservices2', 'path': 'microservices2', 'name': 'microservices2'}, 'id': 8910769, 'path': 'gateway-service', 'web_url': 'https://gitlab.com/microservices2/gateway-service', 'ssh_url_to_repo': 'git@gitlab.com:microservices2/gateway-service.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:19:58.941Z', 'readme_url': 'https://gitlab.com/issue-reproduce/grant-access-from-request/blob/master/README.md', 'last_activity_at': '2018-10-17T11:19:58.941Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'grant-access-from-request', 'description': '', 'http_url_to_repo': 'https://gitlab.com/issue-reproduce/grant-access-from-request.git', '_id': ObjectId('5bc788e42683be47187d4b90'), 'path_with_namespace': 'issue-reproduce/grant-access-from-request', 'name_with_namespace': 'issue-reproduce / grant-access-from-request', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 785414, 'parent_id': None, 'full_path': 'issue-reproduce', 'path': 'issue-reproduce', 'name': 'issue-reproduce'}, 'id': 8910645, 'path': 'grant-access-from-request', 'web_url': 'https://gitlab.com/issue-reproduce/grant-access-from-request', 'ssh_url_to_repo': 'git@gitlab.com:issue-reproduce/grant-access-from-request.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:15:04.982Z', 'readme_url': None, 'last_activity_at': '2018-10-17T11:15:04.982Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'goglobal_bit', 'description': '', 'http_url_to_repo': 'https://gitlab.com/lutersergei/goglobal_bit.git', '_id': ObjectId('5bc788e52683be47187d4b91'), 'path_with_namespace': 'lutersergei/goglobal_bit', 'name_with_namespace': 'luter sergei / goglobal_bit', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3823766, 'parent_id': None, 'full_path': 'lutersergei', 'path': 'lutersergei', 'name': 'lutersergei'}, 'id': 8910571, 'path': 'goglobal_bit', 'web_url': 'https://gitlab.com/lutersergei/goglobal_bit', 'ssh_url_to_repo': 'git@gitlab.com:lutersergei/goglobal_bit.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T11:04:58.336Z', 'readme_url': 'https://gitlab.com/bits4fun/gitlab-oss/blob/master/README.md', 'last_activity_at': '2018-10-17T11:04:58.336Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GitLab OSS - Ultimate or Gold for open source projects', 'description': 'GitLab Ultimate or Gold for open source projects', 'http_url_to_repo': 'https://gitlab.com/bits4fun/gitlab-oss.git', '_id': ObjectId('5bc788e52683be47187d4b92'), 'path_with_namespace': 'bits4fun/gitlab-oss', 'name_with_namespace': 'Bits4Fun / GitLab OSS - Ultimate or Gold for open source projects', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8910064/logo-extra-whitespace.png', 'namespace': {'kind': 'user', 'id': 1382141, 'parent_id': None, 'full_path': 'bits4fun', 'path': 'bits4fun', 'name': 'bits4fun'}, 'id': 8910064, 'path': 'gitlab-oss', 'web_url': 'https://gitlab.com/bits4fun/gitlab-oss', 'ssh_url_to_repo': 'git@gitlab.com:bits4fun/gitlab-oss.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:50:12.208Z', 'readme_url': 'https://gitlab.com/gr33nonline/GhettoVaper/blob/master/README.md', 'last_activity_at': '2018-10-17T10:50:12.208Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GhettoVaper', 'description': 'Arduino Code for a Vaping Box mod', 'http_url_to_repo': 'https://gitlab.com/gr33nonline/GhettoVaper.git', '_id': ObjectId('5bc788e52683be47187d4b93'), 'path_with_namespace': 'gr33nonline/GhettoVaper', 'name_with_namespace': 'Green online / GhettoVaper', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824445, 'parent_id': None, 'full_path': 'gr33nonline', 'path': 'gr33nonline', 'name': 'gr33nonline'}, 'id': 8909506, 'path': 'GhettoVaper', 'web_url': 'https://gitlab.com/gr33nonline/GhettoVaper', 'ssh_url_to_repo': 'git@gitlab.com:gr33nonline/GhettoVaper.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:42:35.843Z', 'readme_url': 'https://gitlab.com/rahmanjai/GameEngineOld/blob/master/README.md', 'last_activity_at': '2018-10-17T10:42:35.843Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GameEngineOld', 'description': None, 'http_url_to_repo': 'https://gitlab.com/rahmanjai/GameEngineOld.git', '_id': ObjectId('5bc788e52683be47187d4b94'), 'path_with_namespace': 'rahmanjai/GameEngineOld', 'name_with_namespace': 'Rahman Jailani / GameEngineOld', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824401, 'parent_id': None, 'full_path': 'rahmanjai', 'path': 'rahmanjai', 'name': 'rahmanjai'}, 'id': 8909414, 'path': 'GameEngineOld', 'web_url': 'https://gitlab.com/rahmanjai/GameEngineOld', 'ssh_url_to_repo': 'git@gitlab.com:rahmanjai/GameEngineOld.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:42:35.811Z', 'readme_url': 'https://gitlab.com/rahmanjai/GameEngine/blob/master/README.md', 'last_activity_at': '2018-10-17T10:42:35.811Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GameEngine', 'description': 'Source Code dari 3D Game tutorial oleh ThinMatrix', 'http_url_to_repo': 'https://gitlab.com/rahmanjai/GameEngine.git', '_id': ObjectId('5bc788e62683be47187d4b95'), 'path_with_namespace': 'rahmanjai/GameEngine', 'name_with_namespace': 'Rahman Jailani / GameEngine', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3824401, 'parent_id': None, 'full_path': 'rahmanjai', 'path': 'rahmanjai', 'name': 'rahmanjai'}, 'id': 8909413, 'path': 'GameEngine', 'web_url': 'https://gitlab.com/rahmanjai/GameEngine', 'ssh_url_to_repo': 'git@gitlab.com:rahmanjai/GameEngine.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:42:02.472Z', 'readme_url': 'https://gitlab.com/biswaz/gale-crawler/blob/master/README.md', 'last_activity_at': '2018-10-17T10:42:02.472Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Gale crawler', 'description': '', 'http_url_to_repo': 'https://gitlab.com/biswaz/gale-crawler.git', '_id': ObjectId('5bc788ea2683be47187d4b96'), 'path_with_namespace': 'biswaz/gale-crawler', 'name_with_namespace': 'Biswas B / Gale crawler', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1387010, 'parent_id': None, 'full_path': 'biswaz', 'path': 'biswaz', 'name': 'biswaz'}, 'id': 8909398, 'path': 'gale-crawler', 'web_url': 'https://gitlab.com/biswaz/gale-crawler', 'ssh_url_to_repo': 'git@gitlab.com:biswaz/gale-crawler.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:19:53.769Z', 'readme_url': 'https://gitlab.com/garyshen/hexo/blob/master/README.md', 'last_activity_at': '2018-10-17T10:19:53.769Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'garyshen.gitlab.io', 'description': 'Example Hexo site using GitLab Pages: https://pages.gitlab.io/hexo', 'http_url_to_repo': 'https://gitlab.com/garyshen/hexo.git', '_id': ObjectId('5bc788eb2683be47187d4b97'), 'path_with_namespace': 'garyshen/hexo', 'name_with_namespace': 'garyshen / garyshen.gitlab.io', 'avatar_url': 'https://assets.gitlab-static.net/uploads/-/system/project/avatar/8909041/hexo.png', 'namespace': {'kind': 'user', 'id': 3821543, 'parent_id': None, 'full_path': 'garyshen', 'path': 'garyshen', 'name': 'garyshen'}, 'id': 8909041, 'path': 'hexo', 'web_url': 'https://gitlab.com/garyshen/hexo', 'ssh_url_to_repo': 'git@gitlab.com:garyshen/hexo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:19:47.094Z', 'readme_url': 'https://gitlab.com/amydin/golangbasic/blob/master/README.md', 'last_activity_at': '2018-10-17T10:19:47.094Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Golang Basic', 'description': '', 'http_url_to_repo': 'https://gitlab.com/amydin/golangbasic.git', '_id': ObjectId('5bc788eb2683be47187d4b98'), 'path_with_namespace': 'amydin/golangbasic', 'name_with_namespace': 'Amydin S / Golang Basic', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2302135, 'parent_id': None, 'full_path': 'amydin', 'path': 'amydin', 'name': 'amydin'}, 'id': 8909038, 'path': 'golangbasic', 'web_url': 'https://gitlab.com/amydin/golangbasic', 'ssh_url_to_repo': 'git@gitlab.com:amydin/golangbasic.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:19:02.842Z', 'readme_url': 'https://gitlab.com/viasisco/gildedrose/blob/master/README.md', 'last_activity_at': '2018-10-17T10:19:02.842Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gildedrose', 'description': '', 'http_url_to_repo': 'https://gitlab.com/viasisco/gildedrose.git', '_id': ObjectId('5bc788eb2683be47187d4b99'), 'path_with_namespace': 'viasisco/gildedrose', 'name_with_namespace': 'DI MARCANTONIO / gildedrose', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 986698, 'parent_id': None, 'full_path': 'viasisco', 'path': 'viasisco', 'name': 'viasisco'}, 'id': 8909023, 'path': 'gildedrose', 'web_url': 'https://gitlab.com/viasisco/gildedrose', 'ssh_url_to_repo': 'git@gitlab.com:viasisco/gildedrose.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:16:39.266Z', 'readme_url': 'https://gitlab.com/leogopal/GyShiDo/blob/master/README.md', 'last_activity_at': '2018-10-17T10:16:39.266Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GyShiDo', 'description': 'Getting Your Shit Done', 'http_url_to_repo': 'https://gitlab.com/leogopal/GyShiDo.git', '_id': ObjectId('5bc788ec2683be47187d4b9a'), 'path_with_namespace': 'leogopal/GyShiDo', 'name_with_namespace': 'Leo Gopal / GyShiDo', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2906034, 'parent_id': None, 'full_path': 'leogopal', 'path': 'leogopal', 'name': 'leogopal'}, 'id': 8908936, 'path': 'GyShiDo', 'web_url': 'https://gitlab.com/leogopal/GyShiDo', 'ssh_url_to_repo': 'git@gitlab.com:leogopal/GyShiDo.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:16:36.687Z', 'readme_url': 'https://gitlab.com/leogopal/gulp-cheatsheet/blob/master/README.md', 'last_activity_at': '2018-10-17T10:16:36.687Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gulp-cheatsheet', 'description': 'A cheatsheet for gulp.js', 'http_url_to_repo': 'https://gitlab.com/leogopal/gulp-cheatsheet.git', '_id': ObjectId('5bc788ec2683be47187d4b9b'), 'path_with_namespace': 'leogopal/gulp-cheatsheet', 'name_with_namespace': 'Leo Gopal / gulp-cheatsheet', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 2906034, 'parent_id': None, 'full_path': 'leogopal', 'path': 'leogopal', 'name': 'leogopal'}, 'id': 8908935, 'path': 'gulp-cheatsheet', 'web_url': 'https://gitlab.com/leogopal/gulp-cheatsheet', 'ssh_url_to_repo': 'git@gitlab.com:leogopal/gulp-cheatsheet.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:11:51.295Z', 'readme_url': None, 'last_activity_at': '2018-10-17T10:11:51.295Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'git-jest-git', 'description': '', 'http_url_to_repo': 'https://gitlab.com/Siemko/git-jest-git.git', '_id': ObjectId('5bc788f12683be47187d4b9c'), 'path_with_namespace': 'Siemko/git-jest-git', 'name_with_namespace': 'Dominik / git-jest-git', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1134740, 'parent_id': None, 'full_path': 'Siemko', 'path': 'Siemko', 'name': 'Siemko'}, 'id': 8908855, 'path': 'git-jest-git', 'web_url': 'https://gitlab.com/Siemko/git-jest-git', 'ssh_url_to_repo': 'git@gitlab.com:Siemko/git-jest-git.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:09:16.262Z', 'readme_url': None, 'last_activity_at': '2018-10-17T10:09:16.262Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'grace', 'description': ' Hoppr\'s Build-Tool/Pkg-Man. "grace [pkg,doc,sys,help]" ', 'http_url_to_repo': 'https://gitlab.com/Terasform/grace.git', '_id': ObjectId('5bc788f12683be47187d4b9d'), 'path_with_namespace': 'Terasform/grace', 'name_with_namespace': ' Terasform Education-Engine. / grace', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3824136, 'parent_id': None, 'full_path': 'Terasform', 'path': 'Terasform', 'name': ' Terasform Education-Engine.'}, 'id': 8908819, 'path': 'grace', 'web_url': 'https://gitlab.com/Terasform/grace', 'ssh_url_to_repo': 'git@gitlab.com:Terasform/grace.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T10:00:28.239Z', 'readme_url': 'https://gitlab.com/vinit.k/guestbook/blob/master/README.md', 'last_activity_at': '2018-10-17T10:00:28.239Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'GuestBook', 'description': '', 'http_url_to_repo': 'https://gitlab.com/vinit.k/guestbook.git', '_id': ObjectId('5bc788f12683be47187d4b9e'), 'path_with_namespace': 'vinit.k/guestbook', 'name_with_namespace': 'Vinit Kumar / GuestBook', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 1686148, 'parent_id': None, 'full_path': 'vinit.k', 'path': 'vinit.k', 'name': 'vinit.k'}, 'id': 8908688, 'path': 'guestbook', 'web_url': 'https://gitlab.com/vinit.k/guestbook', 'ssh_url_to_repo': 'git@gitlab.com:vinit.k/guestbook.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T09:59:09.201Z', 'readme_url': 'https://gitlab.com/bolotweet/gnu-social/blob/master/README.md', 'last_activity_at': '2018-10-17T09:59:09.201Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'gnu-social', 'description': '', 'http_url_to_repo': 'https://gitlab.com/bolotweet/gnu-social.git', '_id': ObjectId('5bc788f22683be47187d4b9f'), 'path_with_namespace': 'bolotweet/gnu-social', 'name_with_namespace': 'bolotweet / gnu-social', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3823903, 'parent_id': None, 'full_path': 'bolotweet', 'path': 'bolotweet', 'name': 'bolotweet'}, 'id': 8908664, 'path': 'gnu-social', 'web_url': 'https://gitlab.com/bolotweet/gnu-social', 'ssh_url_to_repo': 'git@gitlab.com:bolotweet/gnu-social.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T09:55:59.815Z', 'readme_url': 'https://gitlab.com/bolotweet/Grades/blob/master/README.md', 'last_activity_at': '2018-10-17T09:55:59.815Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'Grades', 'description': '', 'http_url_to_repo': 'https://gitlab.com/bolotweet/Grades.git', '_id': ObjectId('5bc788f22683be47187d4ba0'), 'path_with_namespace': 'bolotweet/Grades', 'name_with_namespace': 'bolotweet / Grades', 'avatar_url': None, 'namespace': {'kind': 'group', 'id': 3823903, 'parent_id': None, 'full_path': 'bolotweet', 'path': 'bolotweet', 'name': 'bolotweet'}, 'id': 8908610, 'path': 'Grades', 'web_url': 'https://gitlab.com/bolotweet/Grades', 'ssh_url_to_repo': 'git@gitlab.com:bolotweet/Grades.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T09:39:15.242Z', 'readme_url': 'https://gitlab.com/_Guinome/graphql-workshop/blob/master/README.md', 'last_activity_at': '2018-10-17T09:39:15.242Z', 'tag_list': [], 'default_branch': 'master', 'forge': 'gitlab', 'star_count': 0, 'name': 'graphql-workshop', 'description': '', 'http_url_to_repo': 'https://gitlab.com/_Guinome/graphql-workshop.git', '_id': ObjectId('5bc788f22683be47187d4ba1'), 'path_with_namespace': '_Guinome/graphql-workshop', 'name_with_namespace': 'Guillaume Orsoni / graphql-workshop', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 3569910, 'parent_id': None, 'full_path': '_Guinome', 'path': '_Guinome', 'name': '_Guinome'}, 'id': 8908313, 'path': 'graphql-workshop', 'web_url': 'https://gitlab.com/_Guinome/graphql-workshop', 'ssh_url_to_repo': 'git@gitlab.com:_Guinome/graphql-workshop.git'}
# {'forks_count': 0, 'created_at': '2018-10-17T09:27:58.006Z', 'readme_url': None, 'last_activity_at': '2018-10-17T09:27:58.006Z', 'tag_list': [], 'default_branch': None, 'forge': 'gitlab', 'star_count': 0, 'name': 'gitment-comments', 'description': 'blog-gitment', 'http_url_to_repo': 'https://gitlab.com/NineSwords/gitment-comments.git', '_id': ObjectId('5bc788f32683be47187d4ba2'), 'path_with_namespace': 'NineSwords/gitment-comments', 'name_with_namespace': 'wangjia / gitment-comments', 'avatar_url': None, 'namespace': {'kind': 'user', 'id': 87872, 'parent_id': None, 'full_path': 'NineSwords', 'path': 'NineSwords', 'name': 'NineSwords'}, 'id': 8908070, 'path': 'gitment-comments', 'web_url': 'https://gitlab.com/NineSwords/gitment-comments', 'ssh_url_to_repo': 'git@gitlab.com:NineSwords/gitment-comments.git'}
# {'forge': 'sourceforge', 'labels': [], 'moved_to_url': '', 'status': 'active', 'name': '(G)ebircsbus', 'categories': {'audience': [], 'license': [], 'language': [], 'translation': [], 'topic': [], 'database': [], 'environment': [], 'os': [], 'developmentstatus': []}, 'preferred_support_url': '', 'creation_date': '2012-06-26', 'short_description': 'Simply like this ;)', 'preferred_support_tool': '', 'tools': [{'url': '/p/gebircsbus/files/', 'mount_label': 'Files', 'mount_point': 'files', 'icons': {'32': 'images/downloads_32.png', '48': 'images/downloads_48.png', '24': 'images/downloads_24.png'}, 'tool_label': 'Files', 'installable': False, 'name': 'files'}, {'url': '/p/gebircsbus/tickets/', 'mount_label': 'Tickets', 'mount_point': 'tickets', 'icons': {'32': 'images/tickets_32.png', '48': 'images/tickets_48.png', '24': 'images/tickets_24.png'}, 'tool_label': 'Tickets', 'installable': True, 'name': 'tickets'}, {'url': '/p/gebircsbus/code/', 'mount_label': 'Code', 'mount_point': 'code', 'icons': {'32': 'images/code_32.png', '48': 'images/code_48.png', '24': 'images/code_24.png'}, 'tool_label': 'SVN', 'installable': True, 'name': 'svn'}, {'url': '/p/gebircsbus/summary/', 'tool_label': 'Summary', 'mount_point': 'summary', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'sourceforge_group_id': 805283, 'mount_label': 'Summary', 'installable': False, 'name': 'summary'}, {'url': '/p/gebircsbus/reviews/', 'mount_label': 'Reviews', 'mount_point': 'reviews', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Reviews', 'installable': False, 'name': 'reviews'}, {'url': '/p/gebircsbus/support/', 'mount_label': 'Support', 'mount_point': 'support', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Support', 'installable': False, 'name': 'support'}, {'url': '/p/gebircsbus/activity/', 'mount_label': 'Activity', 'mount_point': 'activity', 'icons': {'32': 'images/admin_32.png', '48': 'images/admin_48.png', '24': 'images/admin_24.png'}, 'tool_label': 'Tool', 'installable': False, 'name': 'activity'}], 'socialnetworks': [], 'url': 'https://sourceforge.net/p/gebircsbus/', 'screenshots': [], 'private': False, 'icon_url': None, 'shortname': 'gebircsbus', 'summary': 'Climb up Mount Nuocca with (G)ebircsbus!', '_id': '4fe9f9cb1be1ce76e0000053', 'external_homepage': '', 'developers': [{'url': 'https://sourceforge.net/u/syxolk/', 'username': 'syxolk', 'name': ' czghans'}], 'video_url': ''}
# ...
# {'forge': 'sourceforge', 'labels': ['gui', 'frontend', 'emulator', 'fs-uae', 'amiga', 'commodore'], 'moved_to_url': '', 'status': 'abandoned', 'name': 'G-FS-UAE', 'categories': {'audience': [{'id': 2, 'fullname': 'End Users/Desktop', 'shortname': 'endusers', 'fullpath': 'Intended Audience :: by End-User Class :: End Users/Desktop'}], 'license': [{'id': 197, 'fullname': 'Public Domain', 'shortname': 'publicdomain', 'fullpath': 'License :: Public Domain'}], 'language': [{'id': 539, 'fullname': 'BASIC', 'shortname': 'proglang_basic', 'fullpath': 'Programming Language :: BASIC'}], 'translation': [], 'topic': [{'id': 80, 'fullname': 'Games/Entertainment', 'shortname': 'games', 'fullpath': 'Topic :: Games/Entertainment'}, {'id': 74, 'fullname': 'Emulators', 'shortname': 'emulators', 'fullpath': 'Topic :: System :: Emulators'}], 'database': [], 'environment': [{'id': 479, 'fullname': 'Qt', 'shortname': 'ui_qt', 'fullpath': 'User Interface :: Toolkits/Libraries :: Qt'}], 'os': [{'id': 201, 'fullname': 'Linux', 'shortname': 'linux', 'fullpath': 'Operating System :: Modern (Vendor-Supported) Desktop Operating Systems :: Linux'}, {'id': 200, 'fullname': 'All POSIX (Linux/BSD/UNIX-like OSes)', 'shortname': 'posix', 'fullpath': 'Operating System :: Grouping and Descriptive Categories :: All POSIX (Linux/BSD/UNIX-like OSes)'}], 'developmentstatus': [{'id': 10, 'fullname': '4 - Beta', 'shortname': 'beta', 'fullpath': 'Development Status :: 4 - Beta'}]}, 'preferred_support_url': '', 'creation_date': '2012-03-04', 'short_description': 'A small interface written in Gambas3 for command line FS-UAE Linux Amiga emulator.', 'preferred_support_tool': '', 'tools': [{'url': '/p/gfsuae/files/', 'mount_label': 'Files', 'mount_point': 'files', 'icons': {'32': 'images/downloads_32.png', '48': 'images/downloads_48.png', '24': 'images/downloads_24.png'}, 'tool_label': 'Files', 'installable': False, 'name': 'files'}, {'url': '/p/gfsuae/tickets/', 'mount_label': 'Tickets', 'mount_point': 'tickets', 'icons': {'32': 'images/tickets_32.png', '48': 'images/tickets_48.png', '24': 'images/tickets_24.png'}, 'tool_label': 'Tickets', 'installable': True, 'name': 'tickets'}, {'url': '/p/gfsuae/reviews/', 'mount_label': 'Reviews', 'mount_point': 'reviews', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Reviews', 'installable': False, 'name': 'reviews'}, {'url': '/p/gfsuae/support/', 'mount_label': 'Support', 'mount_point': 'support', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Support', 'installable': False, 'name': 'support'}, {'url': '/p/gfsuae/summary/', 'tool_label': 'Summary', 'mount_point': 'summary', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'sourceforge_group_id': 713989, 'mount_label': 'Summary', 'installable': False, 'name': 'summary'}, {'url': '/p/gfsuae/activity/', 'mount_label': 'Activity', 'mount_point': 'activity', 'icons': {'32': 'images/admin_32.png', '48': 'images/admin_48.png', '24': 'images/admin_24.png'}, 'tool_label': 'Tool', 'installable': False, 'name': 'activity'}], 'socialnetworks': [{'socialnetwork': 'Twitter', 'accounturl': ''}, {'socialnetwork': 'Facebook', 'accounturl': None}], 'url': 'https://sourceforge.net/p/gfsuae/', 'screenshots': [{'thumbnail_url': 'https://sourceforge.net/p/gfsuae/screenshot/screen3.png/thumb', 'url': 'https://sourceforge.net/p/gfsuae/screenshot/screen3.png', 'caption': 'HD/CD-ROM'}, {'thumbnail_url': 'https://sourceforge.net/p/gfsuae/screenshot/screen4.png/thumb', 'url': 'https://sourceforge.net/p/gfsuae/screenshot/screen4.png', 'caption': 'Net'}, {'thumbnail_url': 'https://sourceforge.net/p/gfsuae/screenshot/screen6.png.png/thumb', 'url': 'https://sourceforge.net/p/gfsuae/screenshot/screen6.png.png', 'caption': ' ...
# {'forge': 'sourceforge', 'labels': [], 'moved_to_url': '', 'status': 'active', 'name': 'G-Framework Web3.0 ToolKit', 'categories': {'audience': [{'id': 3, 'fullname': 'Developers', 'shortname': 'developers', 'fullpath': 'Intended Audience :: by End-User Class :: Developers'}], 'license': [{'id': 15, 'fullname': 'GNU General Public License version 2.0 (GPLv2)', 'shortname': 'gpl', 'fullpath': 'License :: OSI-Approved Open Source :: GNU General Public License version 2.0 (GPLv2)'}], 'language': [{'id': 183, 'fullname': 'PHP', 'shortname': 'php', 'fullpath': 'Programming Language :: PHP'}, {'id': 280, 'fullname': 'JavaScript', 'shortname': 'JavaScript', 'fullpath': 'Programming Language :: JavaScript'}], 'translation': [{'id': 337, 'fullname': 'Italian', 'shortname': 'italian', 'fullpath': 'Translations :: Italian'}, {'id': 275, 'fullname': 'English', 'shortname': 'english', 'fullpath': 'Translations :: English'}], 'topic': [{'id': 559, 'fullname': 'XML', 'shortname': 'xml', 'fullpath': 'Topic :: Formats and Protocols :: Data Formats :: XML'}, {'id': 606, 'fullname': 'Frameworks', 'shortname': 'frameworks', 'fullpath': 'Topic :: Software Development :: Frameworks'}, {'id': 648, 'fullname': 'JSON', 'shortname': 'json', 'fullpath': 'Topic :: Formats and Protocols :: Data Formats :: JSON'}], 'database': [{'id': 524, 'fullname': 'MySQL', 'shortname': 'db_net_mysql', 'fullpath': 'Database Environment :: Network-based DBMS :: MySQL'}, {'id': 530, 'fullname': 'Microsoft SQL Server', 'shortname': 'db_net_mssql', 'fullpath': 'Database Environment :: Network-based DBMS :: Microsoft SQL Server'}], 'environment': [{'id': 237, 'fullname': 'Web-based', 'shortname': 'web', 'fullpath': 'User Interface :: Web-based'}], 'os': [], 'developmentstatus': [{'id': 10, 'fullname': '4 - Beta', 'shortname': 'beta', 'fullpath': 'Development Status :: 4 - Beta'}]}, 'preferred_support_url': 'http://gfwk.soundcafe.it/', 'creation_date': '2008-07-27', 'short_description': 'This is the most advanced and complete new generation tool for creating Web applications. You can create your own "Web Applications" once writing very few lines of code and make it simply accessible from anywhere in the world.', 'preferred_support_tool': '_url', 'tools': [{'url': '/p/gaiaweb30ide/wiki/', 'mount_label': 'Wiki', 'mount_point': 'wiki', 'icons': {'32': 'images/wiki_32.png', '48': 'images/wiki_48.png', '24': 'images/wiki_24.png'}, 'tool_label': 'Wiki', 'installable': True, 'name': 'wiki'}, {'url': '/p/gaiaweb30ide/files/', 'mount_label': 'Files', 'mount_point': 'files', 'icons': {'32': 'images/downloads_32.png', '48': 'images/downloads_48.png', '24': 'images/downloads_24.png'}, 'tool_label': 'Files', 'installable': False, 'name': 'files'}, {'url': '/p/gaiaweb30ide/code/', 'mount_label': 'Code', 'mount_point': 'code', 'icons': {'32': 'images/code_32.png', '48': 'images/code_48.png', '24': 'images/code_24.png'}, 'tool_label': 'Git', 'installable': True, 'name': 'git'}, {'url': '/p/gaiaweb30ide/summary/', 'tool_label': 'Summary', 'mount_point': 'summary', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'sourceforge_group_id': 235238, 'mount_label': 'Summary', 'installable': False, 'name': 'summary'}, {'url': '/p/gaiaweb30ide/support/', 'mount_label': 'Support', 'mount_point': 'support', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Support', 'installable': False, 'name': 'support'}, {'url': '/p/gaiaweb30ide/reviews/', 'mount_label': 'Reviews', 'mount_point': 'reviews', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Reviews', 'installable': False, 'name': 'reviews'}, {'url': '/p/gaiaweb30ide/activity/', 'mount_label': 'Activity', 'mount_point': 'activity', 'icons': {'32': 'images/admin_32.p ...
# {'forge': 'sourceforge', 'labels': [''], 'moved_to_url': '', 'status': 'active', 'name': 'G-Gnome Web-Based OS', 'categories': {'audience': [], 'license': [], 'language': [], 'translation': [], 'topic': [], 'database': [], 'environment': [], 'os': [], 'developmentstatus': []}, 'preferred_support_url': '', 'creation_date': '2010-11-19', 'short_description': 'G-Gnome is a web-based operating system & desktop based on the EyeOS 1.X branch.  We are working to build a better integration to both the resources of the server and the terminal machines.  ', 'preferred_support_tool': '', 'tools': [{'url': '/p/g-gnome/tickets/', 'mount_label': 'Support', 'mount_point': 'tickets', 'icons': {'32': 'images/tickets_32.png', '48': 'images/tickets_48.png', '24': 'images/tickets_24.png'}, 'tool_label': 'Tickets', 'installable': True, 'name': 'tickets'}, {'url': '/p/g-gnome/home/', 'mount_label': 'Home', 'mount_point': 'home', 'icons': {'32': 'images/wiki_32.png', '48': 'images/wiki_48.png', '24': 'images/wiki_24.png'}, 'tool_label': 'Wiki', 'installable': True, 'name': 'wiki'}, {'url': '/p/g-gnome/reviews/', 'mount_label': 'Reviews', 'mount_point': 'reviews', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Reviews', 'installable': False, 'name': 'reviews'}, {'url': '/p/g-gnome/summary/', 'tool_label': 'Summary', 'mount_point': 'summary', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'sourceforge_group_id': 375597, 'mount_label': 'Summary', 'installable': False, 'name': 'summary'}, {'url': '/p/g-gnome/support/', 'mount_label': 'Support', 'mount_point': 'support', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Support', 'installable': False, 'name': 'support'}, {'url': '/p/g-gnome/activity/', 'mount_label': 'Activity', 'mount_point': 'activity', 'icons': {'32': 'images/admin_32.png', '48': 'images/admin_48.png', '24': 'images/admin_24.png'}, 'tool_label': 'Tool', 'installable': False, 'name': 'activity'}], 'socialnetworks': [], 'url': 'https://sourceforge.net/p/g-gnome/', 'screenshots': [], 'private': False, 'icon_url': None, 'shortname': 'g-gnome', 'summary': '', '_id': '4ce707380594ca4e94000502', 'external_homepage': '', 'developers': [{'url': 'https://sourceforge.net/u/g-gnome/', 'username': 'g-gnome', 'name': 'Brian McBride'}], 'video_url': ''}
# {'forge': 'sourceforge', 'labels': [], 'moved_to_url': '', 'status': 'active', 'name': 'G-HOPE', 'categories': {'audience': [{'id': 3, 'fullname': 'Developers', 'shortname': 'developers', 'fullpath': 'Intended Audience :: by End-User Class :: Developers'}], 'license': [{'id': 324, 'fullname': 'Academic Free License (AFL)', 'shortname': 'afl', 'fullpath': 'License :: OSI-Approved Open Source :: Academic Free License (AFL)'}], 'language': [{'id': 198, 'fullname': 'Java', 'shortname': 'java', 'fullpath': 'Programming Language :: Java'}], 'translation': [], 'topic': [{'id': 688, 'fullname': 'Mobile', 'shortname': 'mobileapps', 'fullpath': 'Topic :: Mobile'}], 'database': [], 'environment': [{'id': 583, 'fullname': 'Eclipse', 'shortname': 'eclipse_plugins', 'fullpath': 'User Interface :: Plugins :: Eclipse'}], 'os': [{'id': 728, 'fullname': 'Android', 'shortname': 'android', 'fullpath': 'Operating System :: Handheld/Embedded Operating Systems :: Android'}], 'developmentstatus': [{'id': 7, 'fullname': '1 - Planning', 'shortname': 'planning', 'fullpath': 'Development Status :: 1 - Planning'}]}, 'preferred_support_url': '', 'creation_date': '2011-01-20', 'short_description': 'Term Project by UTD students for Requirement Engineering CS6361.\r\n\r\nG-HOPE (Google "Helping Old People Easily") - A smartphone application for elder with difficulties like lack of hearing, speech impairment, unclear speech, low vision, weak memory etc.', 'preferred_support_tool': '', 'tools': [{'url': '/p/g-hope/reviews/', 'mount_label': 'Reviews', 'mount_point': 'reviews', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Reviews', 'installable': False, 'name': 'reviews'}, {'url': '/p/g-hope/code/', 'mount_label': 'Code', 'mount_point': 'code', 'icons': {'32': 'images/code_32.png', '48': 'images/code_48.png', '24': 'images/code_24.png'}, 'tool_label': 'SVN', 'installable': True, 'name': 'svn'}, {'url': '/p/g-hope/support/', 'mount_label': 'Support', 'mount_point': 'support', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'tool_label': 'Support', 'installable': False, 'name': 'support'}, {'url': '/p/g-hope/summary/', 'tool_label': 'Summary', 'mount_point': 'summary', 'icons': {'32': 'images/sftheme/32x32/blog_32.png', '48': 'images/sftheme/48x48/blog_48.png', '24': 'images/sftheme/24x24/blog_24.png'}, 'sourceforge_group_id': 396517, 'mount_label': 'Summary', 'installable': False, 'name': 'summary'}, {'url': '/p/g-hope/wiki/', 'mount_label': 'Wiki', 'mount_point': 'wiki', 'icons': {'32': 'images/wiki_32.png', '48': 'images/wiki_48.png', '24': 'images/wiki_24.png'}, 'tool_label': 'Wiki', 'installable': True, 'name': 'wiki'}, {'url': '/p/g-hope/files/', 'mount_label': 'Files', 'mount_point': 'files', 'icons': {'32': 'images/downloads_32.png', '48': 'images/downloads_48.png', '24': 'images/downloads_24.png'}, 'tool_label': 'Files', 'installable': False, 'name': 'files'}, {'url': '/p/g-hope/activity/', 'mount_label': 'Activity', 'mount_point': 'activity', 'icons': {'32': 'images/admin_32.png', '48': 'images/admin_48.png', '24': 'images/admin_24.png'}, 'tool_label': 'Tool', 'installable': False, 'name': 'activity'}, {'url': '/p/g-hope/mailman/', 'mount_label': 'Mailing Lists', 'mount_point': 'mailman', 'icons': {'32': 'images/forums_32.png', '48': 'images/forums_48.png', '24': 'images/forums_24.png'}, 'tool_label': 'Mailing Lists', 'installable': False, 'name': 'mailman'}], 'socialnetworks': [], 'url': 'https://sourceforge.net/p/g-hope/', 'screenshots': [], 'private': False, 'icon_url': None, 'shortname': 'g-hope', 'summary': '', '_id': '517abea834309d2f050d1d6e', 'external_homepage': 'http://g-hope.sourceforge.net', 'developers': [{'url': 'https://sourceforge.net/u/hendrasutedja/', 'username': 'hendrasutedja', 'name': 'Hendra Sutedja'}, {'url': 'https://sourceforge.net/u/shri ...
